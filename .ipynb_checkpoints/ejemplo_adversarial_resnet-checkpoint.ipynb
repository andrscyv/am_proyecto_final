# %% [markdown]
# # Creación de un ejemplo adversarial

# %% [markdown]
# Link del tutorial : https://medium.com/mindboard/generating-adversarial-samples-in-keras-tutorial-f881ac836246

# %%
import keras
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten ,Input
from keras.layers import Conv2D, MaxPooling2D, Reshape, Add
from keras.metrics import categorical_accuracy
from keras.regularizers import l1_l2, l2, l1
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from tensorflow.python.keras import backend as K
from keras.preprocessing.image import array_to_img,img_to_array

import matplotlib.pyplot as plt
import numpy as np

from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
##Funciones auxiliares
def plotImage( img, dims = False ):
    if not(dims):
        plt.imshow(img, vmin=0., vmax=1.)
    else: 
        plt.imshow(img.reshape(dims), vmin=0., vmax=1.)
    plt.show()
        

#Instanciacion del modelo resnet
model = ResNet50(weights='imagenet')


##Imagen de elefante
img_path = 'elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plotImage(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x_not_pre = x

# Imagen preprocesada para tener el formato que acepta resnet
x = preprocess_input(x)

# %% [markdown]
# Eligamos una imagen para crear ejemplo adversarial

# %%
#select image to create an adversarial example from
plotImage(x[0])
print(x.shape)
print("Valor máximo %d" % np.max(x))
print("Valor mínimo %d" % np.min(x))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1, 224, 224, 3)
# Valor máximo 151
# Valor mínimo -121

# %% [markdown]
# Veamos qué clasificacion da el modelo

# %%
preds = model.predict(x)
print(preds.shape)
print(np.argmax(preds[0]))
print('Predicción:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# (1, 1000)
# 386
# Predicción: [('n02504458', 'African_elephant', 0.86625427), ('n02504013', 'Indian_elephant', 0.06860924), ('n01871265', 'tusker', 0.06478469)]

# %%
factor = 80
ruido = np.random.normal(loc=0.0, scale=1, size=x.shape)*factor
print('Max valor absoluto del ruido', np.max(np.abs(ruido)))
plotImage(ruido[0])
img_ruido = x + ruido
print("Imagen original")
plotImage(x[0])
print("Imagen ruido")
plotImage(img_ruido[0])
preds = model.predict(img_ruido)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Max valor absoluto del ruido 362.7861729321757
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Imagen original
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Imagen ruido
# Predicted: [('n02999410', 'chain', 0.40553063), ('n02504458', 'African_elephant', 0.27195418), ('n04208210', 'shovel', 0.06421838)]

# %%
#custom loss funciton for non-targeted misclassification
def negative_categorical_crossentropy(yTrue,yPred):
    return 0.0 - K.categorical_crossentropy(yTrue,yPred)

#add custom objects to dictionary
get_custom_objects().update({'negative_categorical_crossentropy': negative_categorical_crossentropy})

def define_adversarial_model(img_shape, regularization, classifier):
    h = img_shape[0]
    w = img_shape[1]
    numChannels = img_shape[2]
    
    #Input imagen base
    image = Input(shape=img_shape,name='image')
    #unidad para ruido adversarial
    one = Input(shape=(1,),name='unity')
    
    #Capa de ruido
    noise = Dense(h*w*numChannels,activation = None,use_bias=False,kernel_initializer='random_normal',
                  kernel_regularizer=regularization, name='adversarial_noise')(one)
    
    #Cambia el shape del ruido igual al de la imagen
    noise = Reshape(img_shape, name='reshape')(noise)
    
    #Suma de las capas
    net = Add(name='add')([noise,image])
    
    #conecta imagen con ruido adversarial a classificador
    outputs = classifier(net)
    outputs = Reshape((1000,), name='reshape_resnet')(outputs)

    adversarial_model = Model(inputs=[image,one], outputs=outputs)
    #vuelve estáticos los parametros del classificador, solo entrena capa de ruido
    adversarial_model.layers[-1].trainable = False
    adversarial_model.layers[-2].trainable = False
    return adversarial_model

def entrena_modelo_adversarial(adversarial_model, target, img, num_epocas):
    target_vector = np.zeros(1000)
    target_vector[target] = 1.
    
    #callback para guardar el modelo 
    checkpoint = ModelCheckpoint('./adversarial_weights_resnet.h5', monitor='loss', verbose=0, save_best_only=True, save_weights_only=True,
                                mode='auto', period=1)
    #entrenamiento
    adversarial_model.fit(x={'image':img,'unity':np.ones(shape=(1,1))},y=target_vector.reshape(1,-1),epochs=num_epocas,verbose=2,
    callbacks=[checkpoint])
    
    #Carga mejores parametros
    adversarial_model.load_weights('./adversarial_weights_resnet.h5')
    
def recupera_ruido(adversarial_model):
    #quantize adversarial noise
    quantized_weights = np.round(adversarial_model.get_weights()[0].reshape((224,224,3)) * 255.) / 255.
    weights = adversarial_model.get_weights()[0].reshape((224,224,3))
    return weights

def clasifica_resnet(img):
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    prediccion =  model.predict(img)
    return decode_predictions(prediccion, top=3)[0]
def clasifica_mod_adversarial(inp, net):
    pred =  net.predict(inp)
    return decode_predictions(pred, top=3)[0]
#generate_adversary(x_not_pre,5,model,l1(0.01),'negative_categorical_crossentropy')

# %%
adversarial_model = define_adversarial_model((224,224,3),l1(0.0000001),model)
adversarial_model.compile(optimizer='nadam', loss='negative_categorical_crossentropy', metrics=[categorical_accuracy])

# %%
target = 386
target_vector = np.zeros((1,1000))
target_vector[0, target] = 1
print(decode_predictions(target_vector, top = 3)[0])
# Out:
# [('n02504458', 'African_elephant', 1.0), ('n15075141', 'toilet_tissue', 0.0), ('n02317335', 'starfish', 0.0)]

# %%
entrena_modelo_adversarial(adversarial_model,target,x, 2000)
# Out:
# [('n02504458', 'African_elephant', 1.0), ('n15075141', 'toilet_tissue', 0.0), ('n02317335', 'starfish', 0.0)]
# Epoch 1/2000
#  - 0s - loss: -9.9972e+00 - categorical_accuracy: 0.0000e+00
# Epoch 2/2000
#  - 0s - loss: -9.9998e+00 - categorical_accuracy: 0.0000e+00
# Epoch 3/2000
#  - 0s - loss: -1.0002e+01 - categorical_accuracy: 0.0000e+00
# Epoch 4/2000
#  - 0s - loss: -1.0005e+01 - categorical_accuracy: 0.0000e+00
# Epoch 5/2000
#  - 0s - loss: -1.0008e+01 - categorical_accuracy: 0.0000e+00
# Epoch 6/2000
#  - 0s - loss: -1.0011e+01 - categorical_accuracy: 0.0000e+00
# Epoch 7/2000
#  - 0s - loss: -1.0014e+01 - categorical_accuracy: 0.0000e+00
# Epoch 8/2000
#  - 0s - loss: -1.0016e+01 - categorical_accuracy: 0.0000e+00
# Epoch 9/2000
#  - 0s - loss: -1.0019e+01 - categorical_accuracy: 0.0000e+00
# Epoch 10/2000
#  - 0s - loss: -1.0022e+01 - categorical_accuracy: 0.0000e+00
# Epoch 11/2000
#  - 0s - loss: -1.0025e+01 - categorical_accuracy: 0.0000e+00
# Epoch 12/2000
#  - 0s - loss: -1.0028e+01 - categorical_accuracy: 0.0000e+00
# Epoch 13/2000
#  - 0s - loss: -1.0030e+01 - categorical_accuracy: 0.0000e+00
# Epoch 14/2000
#  - 0s - loss: -1.0033e+01 - categorical_accuracy: 0.0000e+00
# Epoch 15/2000
#  - 0s - loss: -1.0035e+01 - categorical_accuracy: 0.0000e+00
# Epoch 16/2000
#  - 0s - loss: -1.0038e+01 - categorical_accuracy: 0.0000e+00
# Epoch 17/2000
#  - 0s - loss: -1.0041e+01 - categorical_accuracy: 0.0000e+00
# Epoch 18/2000
#  - 0s - loss: -1.0044e+01 - categorical_accuracy: 0.0000e+00
# Epoch 19/2000
#  - 0s - loss: -1.0047e+01 - categorical_accuracy: 0.0000e+00
# Epoch 20/2000
#  - 0s - loss: -1.0050e+01 - categorical_accuracy: 0.0000e+00
# Epoch 21/2000
#  - 0s - loss: -1.0052e+01 - categorical_accuracy: 0.0000e+00
# Epoch 22/2000
#  - 0s - loss: -1.0056e+01 - categorical_accuracy: 0.0000e+00
# Epoch 23/2000
#  - 0s - loss: -1.0058e+01 - categorical_accuracy: 0.0000e+00
# Epoch 24/2000
#  - 0s - loss: -1.0061e+01 - categorical_accuracy: 0.0000e+00
# Epoch 25/2000
#  - 0s - loss: -1.0063e+01 - categorical_accuracy: 0.0000e+00
# Epoch 26/2000
#  - 0s - loss: -1.0067e+01 - categorical_accuracy: 0.0000e+00
# Epoch 27/2000
#  - 0s - loss: -1.0069e+01 - categorical_accuracy: 0.0000e+00
# Epoch 28/2000
#  - 0s - loss: -1.0072e+01 - categorical_accuracy: 0.0000e+00
# Epoch 29/2000
#  - 0s - loss: -1.0075e+01 - categorical_accuracy: 0.0000e+00
# Epoch 30/2000
#  - 0s - loss: -1.0078e+01 - categorical_accuracy: 0.0000e+00
# Epoch 31/2000
#  - 0s - loss: -1.0081e+01 - categorical_accuracy: 0.0000e+00
# Epoch 32/2000
#  - 0s - loss: -1.0084e+01 - categorical_accuracy: 0.0000e+00
# Epoch 33/2000
#  - 0s - loss: -1.0087e+01 - categorical_accuracy: 0.0000e+00
# Epoch 34/2000
#  - 0s - loss: -1.0090e+01 - categorical_accuracy: 0.0000e+00
# Epoch 35/2000
#  - 0s - loss: -1.0092e+01 - categorical_accuracy: 0.0000e+00
# Epoch 36/2000
#  - 0s - loss: -1.0095e+01 - categorical_accuracy: 0.0000e+00
# Epoch 37/2000
#  - 0s - loss: -1.0098e+01 - categorical_accuracy: 0.0000e+00
# Epoch 38/2000
#  - 0s - loss: -1.0101e+01 - categorical_accuracy: 0.0000e+00
# Epoch 39/2000
#  - 0s - loss: -1.0103e+01 - categorical_accuracy: 0.0000e+00
# Epoch 40/2000
#  - 0s - loss: -1.0106e+01 - categorical_accuracy: 0.0000e+00
# Epoch 41/2000
#  - 0s - loss: -1.0109e+01 - categorical_accuracy: 0.0000e+00
# Epoch 42/2000
#  - 0s - loss: -1.0112e+01 - categorical_accuracy: 0.0000e+00
# Epoch 43/2000
#  - 0s - loss: -1.0114e+01 - categorical_accuracy: 0.0000e+00
# Epoch 44/2000
#  - 0s - loss: -1.0117e+01 - categorical_accuracy: 0.0000e+00
# Epoch 45/2000
#  - 0s - loss: -1.0120e+01 - categorical_accuracy: 0.0000e+00
# Epoch 46/2000
#  - 0s - loss: -1.0123e+01 - categorical_accuracy: 0.0000e+00
# Epoch 47/2000
#  - 0s - loss: -1.0126e+01 - categorical_accuracy: 0.0000e+00
# Epoch 48/2000
#  - 0s - loss: -1.0129e+01 - categorical_accuracy: 0.0000e+00
# Epoch 49/2000
#  - 0s - loss: -1.0131e+01 - categorical_accuracy: 0.0000e+00
# Epoch 50/2000
#  - 0s - loss: -1.0134e+01 - categorical_accuracy: 0.0000e+00
# Epoch 51/2000
#  - 0s - loss: -1.0137e+01 - categorical_accuracy: 0.0000e+00
# Epoch 52/2000
#  - 0s - loss: -1.0140e+01 - categorical_accuracy: 0.0000e+00
# Epoch 53/2000
#  - 0s - loss: -1.0142e+01 - categorical_accuracy: 0.0000e+00
# Epoch 54/2000
#  - 0s - loss: -1.0145e+01 - categorical_accuracy: 0.0000e+00
# Epoch 55/2000
#  - 0s - loss: -1.0147e+01 - categorical_accuracy: 0.0000e+00
# Epoch 56/2000
#  - 0s - loss: -1.0150e+01 - categorical_accuracy: 0.0000e+00
# Epoch 57/2000
#  - 0s - loss: -1.0153e+01 - categorical_accuracy: 0.0000e+00
# Epoch 58/2000
#  - 0s - loss: -1.0156e+01 - categorical_accuracy: 0.0000e+00
# Epoch 59/2000
#  - 0s - loss: -1.0158e+01 - categorical_accuracy: 0.0000e+00
# Epoch 60/2000
#  - 0s - loss: -1.0161e+01 - categorical_accuracy: 0.0000e+00
# Epoch 61/2000
#  - 0s - loss: -1.0163e+01 - categorical_accuracy: 0.0000e+00
# Epoch 62/2000
#  - 0s - loss: -1.0166e+01 - categorical_accuracy: 0.0000e+00
# Epoch 63/2000
#  - 0s - loss: -1.0169e+01 - categorical_accuracy: 0.0000e+00
# Epoch 64/2000
#  - 0s - loss: -1.0172e+01 - categorical_accuracy: 0.0000e+00
# Epoch 65/2000
#  - 0s - loss: -1.0174e+01 - categorical_accuracy: 0.0000e+00
# Epoch 66/2000
#  - 0s - loss: -1.0177e+01 - categorical_accuracy: 0.0000e+00
# Epoch 67/2000
#  - 0s - loss: -1.0179e+01 - categorical_accuracy: 0.0000e+00
# Epoch 68/2000
#  - 0s - loss: -1.0182e+01 - categorical_accuracy: 0.0000e+00
# Epoch 69/2000
#  - 0s - loss: -1.0185e+01 - categorical_accuracy: 0.0000e+00
# Epoch 70/2000
#  - 0s - loss: -1.0188e+01 - categorical_accuracy: 0.0000e+00
# Epoch 71/2000
#  - 0s - loss: -1.0190e+01 - categorical_accuracy: 0.0000e+00
# Epoch 72/2000
#  - 0s - loss: -1.0192e+01 - categorical_accuracy: 0.0000e+00
# Epoch 73/2000
#  - 0s - loss: -1.0195e+01 - categorical_accuracy: 0.0000e+00
# Epoch 74/2000
#  - 0s - loss: -1.0198e+01 - categorical_accuracy: 0.0000e+00
# Epoch 75/2000
#  - 0s - loss: -1.0201e+01 - categorical_accuracy: 0.0000e+00
# Epoch 76/2000
#  - 0s - loss: -1.0203e+01 - categorical_accuracy: 0.0000e+00
# Epoch 77/2000
#  - 0s - loss: -1.0206e+01 - categorical_accuracy: 0.0000e+00
# Epoch 78/2000
#  - 0s - loss: -1.0208e+01 - categorical_accuracy: 0.0000e+00
# Epoch 79/2000
#  - 0s - loss: -1.0211e+01 - categorical_accuracy: 0.0000e+00
# Epoch 80/2000
#  - 0s - loss: -1.0213e+01 - categorical_accuracy: 0.0000e+00
# Epoch 81/2000
#  - 0s - loss: -1.0216e+01 - categorical_accuracy: 0.0000e+00
# Epoch 82/2000
#  - 0s - loss: -1.0219e+01 - categorical_accuracy: 0.0000e+00
# Epoch 83/2000
#  - 0s - loss: -1.0222e+01 - categorical_accuracy: 0.0000e+00
# Epoch 84/2000
#  - 0s - loss: -1.0224e+01 - categorical_accuracy: 0.0000e+00
# Epoch 85/2000
#  - 0s - loss: -1.0227e+01 - categorical_accuracy: 0.0000e+00
# Epoch 86/2000
#  - 0s - loss: -1.0230e+01 - categorical_accuracy: 0.0000e+00
# Epoch 87/2000
#  - 0s - loss: -1.0232e+01 - categorical_accuracy: 0.0000e+00
# Epoch 88/2000
#  - 0s - loss: -1.0234e+01 - categorical_accuracy: 0.0000e+00
# Epoch 89/2000
#  - 0s - loss: -1.0236e+01 - categorical_accuracy: 0.0000e+00
# Epoch 90/2000
#  - 0s - loss: -1.0239e+01 - categorical_accuracy: 0.0000e+00
# Epoch 91/2000
#  - 0s - loss: -1.0242e+01 - categorical_accuracy: 0.0000e+00
# Epoch 92/2000
#  - 0s - loss: -1.0245e+01 - categorical_accuracy: 0.0000e+00
# Epoch 93/2000
#  - 0s - loss: -1.0247e+01 - categorical_accuracy: 0.0000e+00
# Epoch 94/2000
#  - 0s - loss: -1.0250e+01 - categorical_accuracy: 0.0000e+00
# Epoch 95/2000
#  - 0s - loss: -1.0252e+01 - categorical_accuracy: 0.0000e+00
# Epoch 96/2000
#  - 0s - loss: -1.0255e+01 - categorical_accuracy: 0.0000e+00
# Epoch 97/2000
#  - 0s - loss: -1.0258e+01 - categorical_accuracy: 0.0000e+00
# Epoch 98/2000
#  - 0s - loss: -1.0261e+01 - categorical_accuracy: 0.0000e+00
# Epoch 99/2000
#  - 0s - loss: -1.0263e+01 - categorical_accuracy: 0.0000e+00
# Epoch 100/2000
#  - 0s - loss: -1.0265e+01 - categorical_accuracy: 0.0000e+00
# Epoch 101/2000
#  - 0s - loss: -1.0268e+01 - categorical_accuracy: 0.0000e+00
# Epoch 102/2000
#  - 0s - loss: -1.0271e+01 - categorical_accuracy: 0.0000e+00
# Epoch 103/2000
#  - 0s - loss: -1.0274e+01 - categorical_accuracy: 0.0000e+00
# Epoch 104/2000
#  - 0s - loss: -1.0276e+01 - categorical_accuracy: 0.0000e+00
# Epoch 105/2000
#  - 0s - loss: -1.0279e+01 - categorical_accuracy: 0.0000e+00
# Epoch 106/2000
#  - 0s - loss: -1.0281e+01 - categorical_accuracy: 0.0000e+00
# Epoch 107/2000
#  - 0s - loss: -1.0284e+01 - categorical_accuracy: 0.0000e+00
# Epoch 108/2000
#  - 0s - loss: -1.0286e+01 - categorical_accuracy: 0.0000e+00
# Epoch 109/2000
#  - 0s - loss: -1.0289e+01 - categorical_accuracy: 0.0000e+00
# Epoch 110/2000
#  - 0s - loss: -1.0292e+01 - categorical_accuracy: 0.0000e+00
# Epoch 111/2000
#  - 0s - loss: -1.0294e+01 - categorical_accuracy: 0.0000e+00
# Epoch 112/2000
#  - 0s - loss: -1.0297e+01 - categorical_accuracy: 0.0000e+00
# Epoch 113/2000
#  - 0s - loss: -1.0299e+01 - categorical_accuracy: 0.0000e+00
# Epoch 114/2000
#  - 0s - loss: -1.0302e+01 - categorical_accuracy: 0.0000e+00
# Epoch 115/2000
#  - 0s - loss: -1.0305e+01 - categorical_accuracy: 0.0000e+00
# Epoch 116/2000
#  - 0s - loss: -1.0307e+01 - categorical_accuracy: 0.0000e+00
# Epoch 117/2000
#  - 0s - loss: -1.0310e+01 - categorical_accuracy: 0.0000e+00
# Epoch 118/2000
#  - 0s - loss: -1.0312e+01 - categorical_accuracy: 0.0000e+00
# Epoch 119/2000
#  - 0s - loss: -1.0315e+01 - categorical_accuracy: 0.0000e+00
# Epoch 120/2000
#  - 0s - loss: -1.0318e+01 - categorical_accuracy: 0.0000e+00
# Epoch 121/2000
#  - 0s - loss: -1.0320e+01 - categorical_accuracy: 0.0000e+00
# Epoch 122/2000
#  - 0s - loss: -1.0323e+01 - categorical_accuracy: 0.0000e+00
# Epoch 123/2000
#  - 0s - loss: -1.0325e+01 - categorical_accuracy: 0.0000e+00
# Epoch 124/2000
#  - 0s - loss: -1.0327e+01 - categorical_accuracy: 0.0000e+00
# Epoch 125/2000
#  - 0s - loss: -1.0330e+01 - categorical_accuracy: 0.0000e+00
# Epoch 126/2000
#  - 0s - loss: -1.0332e+01 - categorical_accuracy: 0.0000e+00
# Epoch 127/2000
#  - 0s - loss: -1.0335e+01 - categorical_accuracy: 0.0000e+00
# Epoch 128/2000
#  - 0s - loss: -1.0337e+01 - categorical_accuracy: 0.0000e+00
# Epoch 129/2000
#  - 0s - loss: -1.0340e+01 - categorical_accuracy: 0.0000e+00
# Epoch 130/2000
#  - 0s - loss: -1.0342e+01 - categorical_accuracy: 0.0000e+00
# Epoch 131/2000
#  - 0s - loss: -1.0345e+01 - categorical_accuracy: 0.0000e+00
# Epoch 132/2000
#  - 0s - loss: -1.0348e+01 - categorical_accuracy: 0.0000e+00
# Epoch 133/2000
#  - 0s - loss: -1.0349e+01 - categorical_accuracy: 0.0000e+00
# Epoch 134/2000
#  - 0s - loss: -1.0352e+01 - categorical_accuracy: 0.0000e+00
# Epoch 135/2000
#  - 0s - loss: -1.0354e+01 - categorical_accuracy: 0.0000e+00
# Epoch 136/2000
#  - 0s - loss: -1.0357e+01 - categorical_accuracy: 0.0000e+00
# Epoch 137/2000
#  - 0s - loss: -1.0360e+01 - categorical_accuracy: 0.0000e+00
# Epoch 138/2000
#  - 0s - loss: -1.0362e+01 - categorical_accuracy: 0.0000e+00
# Epoch 139/2000
#  - 0s - loss: -1.0364e+01 - categorical_accuracy: 0.0000e+00
# Epoch 140/2000
#  - 0s - loss: -1.0367e+01 - categorical_accuracy: 0.0000e+00
# Epoch 141/2000
#  - 0s - loss: -1.0369e+01 - categorical_accuracy: 0.0000e+00
# Epoch 142/2000
#  - 0s - loss: -1.0372e+01 - categorical_accuracy: 0.0000e+00
# Epoch 143/2000
#  - 0s - loss: -1.0374e+01 - categorical_accuracy: 0.0000e+00
# Epoch 144/2000
#  - 0s - loss: -1.0377e+01 - categorical_accuracy: 0.0000e+00
# Epoch 145/2000
#  - 0s - loss: -1.0379e+01 - categorical_accuracy: 0.0000e+00
# Epoch 146/2000
#  - 0s - loss: -1.0382e+01 - categorical_accuracy: 0.0000e+00
# Epoch 147/2000
#  - 0s - loss: -1.0384e+01 - categorical_accuracy: 0.0000e+00
# Epoch 148/2000
#  - 0s - loss: -1.0386e+01 - categorical_accuracy: 0.0000e+00
# Epoch 149/2000
#  - 0s - loss: -1.0389e+01 - categorical_accuracy: 0.0000e+00
# Epoch 150/2000
#  - 0s - loss: -1.0391e+01 - categorical_accuracy: 0.0000e+00
# Epoch 151/2000
#  - 0s - loss: -1.0393e+01 - categorical_accuracy: 0.0000e+00
# Epoch 152/2000
#  - 0s - loss: -1.0396e+01 - categorical_accuracy: 0.0000e+00
# Epoch 153/2000
#  - 0s - loss: -1.0398e+01 - categorical_accuracy: 0.0000e+00
# Epoch 154/2000
#  - 0s - loss: -1.0400e+01 - categorical_accuracy: 0.0000e+00
# Epoch 155/2000
#  - 0s - loss: -1.0403e+01 - categorical_accuracy: 0.0000e+00
# Epoch 156/2000
#  - 0s - loss: -1.0406e+01 - categorical_accuracy: 0.0000e+00
# Epoch 157/2000
#  - 0s - loss: -1.0408e+01 - categorical_accuracy: 0.0000e+00
# Epoch 158/2000
#  - 0s - loss: -1.0411e+01 - categorical_accuracy: 0.0000e+00
# Epoch 159/2000
#  - 0s - loss: -1.0413e+01 - categorical_accuracy: 0.0000e+00
# Epoch 160/2000
#  - 0s - loss: -1.0415e+01 - categorical_accuracy: 0.0000e+00
# Epoch 161/2000
#  - 0s - loss: -1.0418e+01 - categorical_accuracy: 0.0000e+00
# Epoch 162/2000
#  - 0s - loss: -1.0420e+01 - categorical_accuracy: 0.0000e+00
# Epoch 163/2000
#  - 0s - loss: -1.0423e+01 - categorical_accuracy: 0.0000e+00
# Epoch 164/2000
#  - 0s - loss: -1.0425e+01 - categorical_accuracy: 0.0000e+00
# Epoch 165/2000
#  - 0s - loss: -1.0428e+01 - categorical_accuracy: 0.0000e+00
# Epoch 166/2000
#  - 0s - loss: -1.0430e+01 - categorical_accuracy: 0.0000e+00
# Epoch 167/2000
#  - 0s - loss: -1.0433e+01 - categorical_accuracy: 0.0000e+00
# Epoch 168/2000
#  - 0s - loss: -1.0436e+01 - categorical_accuracy: 0.0000e+00
# Epoch 169/2000
#  - 0s - loss: -1.0438e+01 - categorical_accuracy: 0.0000e+00
# Epoch 170/2000
#  - 0s - loss: -1.0440e+01 - categorical_accuracy: 0.0000e+00
# Epoch 171/2000
#  - 0s - loss: -1.0442e+01 - categorical_accuracy: 0.0000e+00
# Epoch 172/2000
#  - 0s - loss: -1.0445e+01 - categorical_accuracy: 0.0000e+00
# Epoch 173/2000
#  - 0s - loss: -1.0447e+01 - categorical_accuracy: 0.0000e+00
# Epoch 174/2000
#  - 0s - loss: -1.0449e+01 - categorical_accuracy: 0.0000e+00
# Epoch 175/2000
#  - 0s - loss: -1.0452e+01 - categorical_accuracy: 0.0000e+00
# Epoch 176/2000
#  - 0s - loss: -1.0454e+01 - categorical_accuracy: 0.0000e+00
# Epoch 177/2000
#  - 0s - loss: -1.0457e+01 - categorical_accuracy: 0.0000e+00
# Epoch 178/2000
#  - 0s - loss: -1.0459e+01 - categorical_accuracy: 0.0000e+00
# Epoch 179/2000
#  - 0s - loss: -1.0461e+01 - categorical_accuracy: 0.0000e+00
# Epoch 180/2000
#  - 0s - loss: -1.0464e+01 - categorical_accuracy: 0.0000e+00
# Epoch 181/2000
#  - 0s - loss: -1.0466e+01 - categorical_accuracy: 0.0000e+00
# Epoch 182/2000
#  - 0s - loss: -1.0469e+01 - categorical_accuracy: 0.0000e+00
# Epoch 183/2000
#  - 0s - loss: -1.0471e+01 - categorical_accuracy: 0.0000e+00
# Epoch 184/2000
#  - 0s - loss: -1.0473e+01 - categorical_accuracy: 0.0000e+00
# Epoch 185/2000
#  - 0s - loss: -1.0475e+01 - categorical_accuracy: 0.0000e+00
# Epoch 186/2000
#  - 0s - loss: -1.0478e+01 - categorical_accuracy: 0.0000e+00
# Epoch 187/2000
#  - 0s - loss: -1.0480e+01 - categorical_accuracy: 0.0000e+00
# Epoch 188/2000
#  - 0s - loss: -1.0482e+01 - categorical_accuracy: 0.0000e+00
# Epoch 189/2000
#  - 0s - loss: -1.0485e+01 - categorical_accuracy: 0.0000e+00
# Epoch 190/2000
#  - 0s - loss: -1.0487e+01 - categorical_accuracy: 0.0000e+00
# Epoch 191/2000
#  - 0s - loss: -1.0490e+01 - categorical_accuracy: 0.0000e+00
# Epoch 192/2000
#  - 0s - loss: -1.0492e+01 - categorical_accuracy: 0.0000e+00
# Epoch 193/2000
#  - 0s - loss: -1.0494e+01 - categorical_accuracy: 0.0000e+00
# Epoch 194/2000
#  - 0s - loss: -1.0496e+01 - categorical_accuracy: 0.0000e+00
# Epoch 195/2000
#  - 0s - loss: -1.0499e+01 - categorical_accuracy: 0.0000e+00
# Epoch 196/2000
#  - 0s - loss: -1.0501e+01 - categorical_accuracy: 0.0000e+00
# Epoch 197/2000
#  - 0s - loss: -1.0503e+01 - categorical_accuracy: 0.0000e+00
# Epoch 198/2000
#  - 0s - loss: -1.0505e+01 - categorical_accuracy: 0.0000e+00
# Epoch 199/2000
#  - 0s - loss: -1.0508e+01 - categorical_accuracy: 0.0000e+00
# Epoch 200/2000
#  - 0s - loss: -1.0510e+01 - categorical_accuracy: 0.0000e+00
# Epoch 201/2000
#  - 0s - loss: -1.0512e+01 - categorical_accuracy: 0.0000e+00
# Epoch 202/2000
#  - 0s - loss: -1.0515e+01 - categorical_accuracy: 0.0000e+00
# Epoch 203/2000
#  - 0s - loss: -1.0517e+01 - categorical_accuracy: 0.0000e+00
# Epoch 204/2000
#  - 0s - loss: -1.0519e+01 - categorical_accuracy: 0.0000e+00
# Epoch 205/2000
#  - 0s - loss: -1.0522e+01 - categorical_accuracy: 0.0000e+00
# Epoch 206/2000
#  - 0s - loss: -1.0524e+01 - categorical_accuracy: 0.0000e+00
# Epoch 207/2000
#  - 0s - loss: -1.0526e+01 - categorical_accuracy: 0.0000e+00
# Epoch 208/2000
#  - 0s - loss: -1.0528e+01 - categorical_accuracy: 0.0000e+00
# Epoch 209/2000
#  - 0s - loss: -1.0531e+01 - categorical_accuracy: 0.0000e+00
# Epoch 210/2000
#  - 0s - loss: -1.0533e+01 - categorical_accuracy: 0.0000e+00
# Epoch 211/2000
#  - 0s - loss: -1.0535e+01 - categorical_accuracy: 0.0000e+00
# Epoch 212/2000
#  - 0s - loss: -1.0538e+01 - categorical_accuracy: 0.0000e+00
# Epoch 213/2000
#  - 0s - loss: -1.0540e+01 - categorical_accuracy: 0.0000e+00
# Epoch 214/2000
#  - 0s - loss: -1.0542e+01 - categorical_accuracy: 0.0000e+00
# Epoch 215/2000
#  - 0s - loss: -1.0544e+01 - categorical_accuracy: 0.0000e+00
# Epoch 216/2000
#  - 0s - loss: -1.0547e+01 - categorical_accuracy: 0.0000e+00
# Epoch 217/2000
#  - 0s - loss: -1.0549e+01 - categorical_accuracy: 0.0000e+00
# Epoch 218/2000
#  - 0s - loss: -1.0551e+01 - categorical_accuracy: 0.0000e+00
# Epoch 219/2000
#  - 0s - loss: -1.0554e+01 - categorical_accuracy: 0.0000e+00
# Epoch 220/2000
#  - 0s - loss: -1.0556e+01 - categorical_accuracy: 0.0000e+00
# Epoch 221/2000
#  - 0s - loss: -1.0558e+01 - categorical_accuracy: 0.0000e+00
# Epoch 222/2000
#  - 0s - loss: -1.0561e+01 - categorical_accuracy: 0.0000e+00
# Epoch 223/2000
#  - 0s - loss: -1.0563e+01 - categorical_accuracy: 0.0000e+00
# Epoch 224/2000
#  - 0s - loss: -1.0565e+01 - categorical_accuracy: 0.0000e+00
# Epoch 225/2000
#  - 0s - loss: -1.0567e+01 - categorical_accuracy: 0.0000e+00
# Epoch 226/2000
#  - 0s - loss: -1.0570e+01 - categorical_accuracy: 0.0000e+00
# Epoch 227/2000
#  - 0s - loss: -1.0572e+01 - categorical_accuracy: 0.0000e+00
# Epoch 228/2000
#  - 0s - loss: -1.0574e+01 - categorical_accuracy: 0.0000e+00
# Epoch 229/2000
#  - 0s - loss: -1.0577e+01 - categorical_accuracy: 0.0000e+00
# Epoch 230/2000
#  - 0s - loss: -1.0579e+01 - categorical_accuracy: 0.0000e+00
# Epoch 231/2000
#  - 0s - loss: -1.0581e+01 - categorical_accuracy: 0.0000e+00
# Epoch 232/2000
#  - 0s - loss: -1.0584e+01 - categorical_accuracy: 0.0000e+00
# Epoch 233/2000
#  - 0s - loss: -1.0586e+01 - categorical_accuracy: 0.0000e+00
# Epoch 234/2000
#  - 0s - loss: -1.0588e+01 - categorical_accuracy: 0.0000e+00
# Epoch 235/2000
#  - 0s - loss: -1.0590e+01 - categorical_accuracy: 0.0000e+00
# Epoch 236/2000
#  - 0s - loss: -1.0593e+01 - categorical_accuracy: 0.0000e+00
# Epoch 237/2000
#  - 0s - loss: -1.0595e+01 - categorical_accuracy: 0.0000e+00
# Epoch 238/2000
#  - 0s - loss: -1.0597e+01 - categorical_accuracy: 0.0000e+00
# Epoch 239/2000
#  - 0s - loss: -1.0599e+01 - categorical_accuracy: 0.0000e+00
# Epoch 240/2000
#  - 0s - loss: -1.0602e+01 - categorical_accuracy: 0.0000e+00
# Epoch 241/2000
#  - 0s - loss: -1.0603e+01 - categorical_accuracy: 0.0000e+00
# Epoch 242/2000
#  - 0s - loss: -1.0606e+01 - categorical_accuracy: 0.0000e+00
# Epoch 243/2000
#  - 0s - loss: -1.0607e+01 - categorical_accuracy: 0.0000e+00
# Epoch 244/2000
#  - 0s - loss: -1.0611e+01 - categorical_accuracy: 0.0000e+00
# Epoch 245/2000
#  - 0s - loss: -1.0613e+01 - categorical_accuracy: 0.0000e+00
# Epoch 246/2000
#  - 0s - loss: -1.0615e+01 - categorical_accuracy: 0.0000e+00
# Epoch 247/2000
#  - 0s - loss: -1.0618e+01 - categorical_accuracy: 0.0000e+00
# Epoch 248/2000
#  - 0s - loss: -1.0620e+01 - categorical_accuracy: 0.0000e+00
# Epoch 249/2000
#  - 0s - loss: -1.0621e+01 - categorical_accuracy: 0.0000e+00
# Epoch 250/2000
#  - 0s - loss: -1.0624e+01 - categorical_accuracy: 0.0000e+00
# Epoch 251/2000
#  - 0s - loss: -1.0626e+01 - categorical_accuracy: 0.0000e+00
# Epoch 252/2000
#  - 0s - loss: -1.0628e+01 - categorical_accuracy: 0.0000e+00
# Epoch 253/2000
#  - 0s - loss: -1.0630e+01 - categorical_accuracy: 0.0000e+00
# Epoch 254/2000
#  - 0s - loss: -1.0633e+01 - categorical_accuracy: 0.0000e+00
# Epoch 255/2000
#  - 0s - loss: -1.0635e+01 - categorical_accuracy: 0.0000e+00
# Epoch 256/2000
#  - 0s - loss: -1.0636e+01 - categorical_accuracy: 0.0000e+00
# Epoch 257/2000
#  - 0s - loss: -1.0639e+01 - categorical_accuracy: 0.0000e+00
# Epoch 258/2000
#  - 0s - loss: -1.0641e+01 - categorical_accuracy: 0.0000e+00
# Epoch 259/2000
#  - 0s - loss: -1.0643e+01 - categorical_accuracy: 0.0000e+00
# Epoch 260/2000
#  - 0s - loss: -1.0646e+01 - categorical_accuracy: 0.0000e+00
# Epoch 261/2000
#  - 0s - loss: -1.0648e+01 - categorical_accuracy: 0.0000e+00
# Epoch 262/2000
#  - 0s - loss: -1.0650e+01 - categorical_accuracy: 0.0000e+00
# Epoch 263/2000
#  - 0s - loss: -1.0651e+01 - categorical_accuracy: 0.0000e+00
# Epoch 264/2000
#  - 0s - loss: -1.0653e+01 - categorical_accuracy: 0.0000e+00
# Epoch 265/2000
#  - 0s - loss: -1.0657e+01 - categorical_accuracy: 0.0000e+00
# Epoch 266/2000
#  - 0s - loss: -1.0659e+01 - categorical_accuracy: 0.0000e+00
# Epoch 267/2000
#  - 0s - loss: -1.0661e+01 - categorical_accuracy: 0.0000e+00
# Epoch 268/2000
#  - 0s - loss: -1.0663e+01 - categorical_accuracy: 0.0000e+00
# Epoch 269/2000
#  - 0s - loss: -1.0664e+01 - categorical_accuracy: 0.0000e+00
# Epoch 270/2000
#  - 0s - loss: -1.0667e+01 - categorical_accuracy: 0.0000e+00
# Epoch 271/2000
#  - 0s - loss: -1.0669e+01 - categorical_accuracy: 0.0000e+00
# Epoch 272/2000
#  - 0s - loss: -1.0671e+01 - categorical_accuracy: 0.0000e+00
# Epoch 273/2000
#  - 0s - loss: -1.0674e+01 - categorical_accuracy: 0.0000e+00
# Epoch 274/2000
#  - 0s - loss: -1.0676e+01 - categorical_accuracy: 0.0000e+00
# Epoch 275/2000
#  - 0s - loss: -1.0678e+01 - categorical_accuracy: 0.0000e+00
# Epoch 276/2000
#  - 0s - loss: -1.0679e+01 - categorical_accuracy: 0.0000e+00
# Epoch 277/2000
#  - 0s - loss: -1.0682e+01 - categorical_accuracy: 0.0000e+00
# Epoch 278/2000
#  - 0s - loss: -1.0684e+01 - categorical_accuracy: 0.0000e+00
# Epoch 279/2000
#  - 0s - loss: -1.0686e+01 - categorical_accuracy: 0.0000e+00
# Epoch 280/2000
#  - 0s - loss: -1.0688e+01 - categorical_accuracy: 0.0000e+00
# Epoch 281/2000
#  - 0s - loss: -1.0690e+01 - categorical_accuracy: 0.0000e+00
# Epoch 282/2000
#  - 0s - loss: -1.0692e+01 - categorical_accuracy: 0.0000e+00
# Epoch 283/2000
#  - 0s - loss: -1.0694e+01 - categorical_accuracy: 0.0000e+00
# Epoch 284/2000
#  - 0s - loss: -1.0696e+01 - categorical_accuracy: 0.0000e+00
# Epoch 285/2000
#  - 0s - loss: -1.0698e+01 - categorical_accuracy: 0.0000e+00
# Epoch 286/2000
#  - 0s - loss: -1.0700e+01 - categorical_accuracy: 0.0000e+00
# Epoch 287/2000
#  - 0s - loss: -1.0702e+01 - categorical_accuracy: 0.0000e+00
# Epoch 288/2000
#  - 0s - loss: -1.0705e+01 - categorical_accuracy: 0.0000e+00
# Epoch 289/2000
#  - 0s - loss: -1.0706e+01 - categorical_accuracy: 0.0000e+00
# Epoch 290/2000
#  - 0s - loss: -1.0708e+01 - categorical_accuracy: 0.0000e+00
# Epoch 291/2000
#  - 0s - loss: -1.0710e+01 - categorical_accuracy: 0.0000e+00
# Epoch 292/2000
#  - 0s - loss: -1.0713e+01 - categorical_accuracy: 0.0000e+00
# Epoch 293/2000
#  - 0s - loss: -1.0715e+01 - categorical_accuracy: 0.0000e+00
# Epoch 294/2000
#  - 0s - loss: -1.0717e+01 - categorical_accuracy: 0.0000e+00
# Epoch 295/2000
#  - 0s - loss: -1.0719e+01 - categorical_accuracy: 0.0000e+00
# Epoch 296/2000
#  - 0s - loss: -1.0720e+01 - categorical_accuracy: 0.0000e+00
# Epoch 297/2000
#  - 0s - loss: -1.0722e+01 - categorical_accuracy: 0.0000e+00
# Epoch 298/2000
#  - 0s - loss: -1.0724e+01 - categorical_accuracy: 0.0000e+00
# Epoch 299/2000
#  - 0s - loss: -1.0726e+01 - categorical_accuracy: 0.0000e+00
# Epoch 300/2000
#  - 0s - loss: -1.0728e+01 - categorical_accuracy: 0.0000e+00
# Epoch 301/2000
#  - 0s - loss: -1.0731e+01 - categorical_accuracy: 0.0000e+00
# Epoch 302/2000
#  - 0s - loss: -1.0732e+01 - categorical_accuracy: 0.0000e+00
# Epoch 303/2000
#  - 0s - loss: -1.0734e+01 - categorical_accuracy: 0.0000e+00
# Epoch 304/2000
#  - 0s - loss: -1.0737e+01 - categorical_accuracy: 0.0000e+00
# Epoch 305/2000
#  - 0s - loss: -1.0738e+01 - categorical_accuracy: 0.0000e+00
# Epoch 306/2000
#  - 0s - loss: -1.0739e+01 - categorical_accuracy: 0.0000e+00
# Epoch 307/2000
#  - 0s - loss: -1.0742e+01 - categorical_accuracy: 0.0000e+00
# Epoch 308/2000
#  - 0s - loss: -1.0744e+01 - categorical_accuracy: 0.0000e+00
# Epoch 309/2000
#  - 0s - loss: -1.0746e+01 - categorical_accuracy: 0.0000e+00
# Epoch 310/2000
#  - 0s - loss: -1.0748e+01 - categorical_accuracy: 0.0000e+00
# Epoch 311/2000
#  - 0s - loss: -1.0749e+01 - categorical_accuracy: 0.0000e+00
# Epoch 312/2000
#  - 0s - loss: -1.0752e+01 - categorical_accuracy: 0.0000e+00
# Epoch 313/2000
#  - 0s - loss: -1.0754e+01 - categorical_accuracy: 0.0000e+00
# Epoch 314/2000
#  - 0s - loss: -1.0756e+01 - categorical_accuracy: 0.0000e+00
# Epoch 315/2000
#  - 0s - loss: -1.0758e+01 - categorical_accuracy: 0.0000e+00
# Epoch 316/2000
#  - 0s - loss: -1.0759e+01 - categorical_accuracy: 0.0000e+00
# Epoch 317/2000
#  - 0s - loss: -1.0762e+01 - categorical_accuracy: 0.0000e+00
# Epoch 318/2000
#  - 0s - loss: -1.0763e+01 - categorical_accuracy: 0.0000e+00
# Epoch 319/2000
#  - 0s - loss: -1.0766e+01 - categorical_accuracy: 0.0000e+00
# Epoch 320/2000
#  - 0s - loss: -1.0768e+01 - categorical_accuracy: 0.0000e+00
# Epoch 321/2000
#  - 0s - loss: -1.0770e+01 - categorical_accuracy: 0.0000e+00
# Epoch 322/2000
#  - 0s - loss: -1.0772e+01 - categorical_accuracy: 0.0000e+00
# Epoch 323/2000
#  - 0s - loss: -1.0774e+01 - categorical_accuracy: 0.0000e+00
# Epoch 324/2000
#  - 0s - loss: -1.0775e+01 - categorical_accuracy: 0.0000e+00
# Epoch 325/2000
#  - 0s - loss: -1.0778e+01 - categorical_accuracy: 0.0000e+00
# Epoch 326/2000
#  - 0s - loss: -1.0780e+01 - categorical_accuracy: 0.0000e+00
# Epoch 327/2000
#  - 0s - loss: -1.0782e+01 - categorical_accuracy: 0.0000e+00
# Epoch 328/2000
#  - 0s - loss: -1.0784e+01 - categorical_accuracy: 0.0000e+00
# Epoch 329/2000
#  - 0s - loss: -1.0786e+01 - categorical_accuracy: 0.0000e+00
# Epoch 330/2000
#  - 0s - loss: -1.0788e+01 - categorical_accuracy: 0.0000e+00
# Epoch 331/2000
#  - 0s - loss: -1.0789e+01 - categorical_accuracy: 0.0000e+00
# Epoch 332/2000
#  - 0s - loss: -1.0790e+01 - categorical_accuracy: 0.0000e+00
# Epoch 333/2000
#  - 0s - loss: -1.0792e+01 - categorical_accuracy: 0.0000e+00
# Epoch 334/2000
#  - 0s - loss: -1.0795e+01 - categorical_accuracy: 0.0000e+00
# Epoch 335/2000
#  - 0s - loss: -1.0797e+01 - categorical_accuracy: 0.0000e+00
# Epoch 336/2000
#  - 0s - loss: -1.0799e+01 - categorical_accuracy: 0.0000e+00
# Epoch 337/2000
#  - 0s - loss: -1.0800e+01 - categorical_accuracy: 0.0000e+00
# Epoch 338/2000
#  - 0s - loss: -1.0802e+01 - categorical_accuracy: 0.0000e+00
# Epoch 339/2000
#  - 0s - loss: -1.0804e+01 - categorical_accuracy: 0.0000e+00
# Epoch 340/2000
#  - 0s - loss: -1.0806e+01 - categorical_accuracy: 0.0000e+00
# Epoch 341/2000
#  - 0s - loss: -1.0808e+01 - categorical_accuracy: 0.0000e+00
# Epoch 342/2000
#  - 0s - loss: -1.0810e+01 - categorical_accuracy: 0.0000e+00
# Epoch 343/2000
#  - 0s - loss: -1.0812e+01 - categorical_accuracy: 0.0000e+00
# Epoch 344/2000
#  - 0s - loss: -1.0814e+01 - categorical_accuracy: 0.0000e+00
# Epoch 345/2000
#  - 0s - loss: -1.0816e+01 - categorical_accuracy: 0.0000e+00
# Epoch 346/2000
#  - 0s - loss: -1.0817e+01 - categorical_accuracy: 0.0000e+00
# Epoch 347/2000
#  - 0s - loss: -1.0819e+01 - categorical_accuracy: 0.0000e+00
# Epoch 348/2000
#  - 0s - loss: -1.0821e+01 - categorical_accuracy: 0.0000e+00
# Epoch 349/2000
#  - 0s - loss: -1.0823e+01 - categorical_accuracy: 0.0000e+00
# Epoch 350/2000
#  - 0s - loss: -1.0825e+01 - categorical_accuracy: 0.0000e+00
# Epoch 351/2000
#  - 0s - loss: -1.0827e+01 - categorical_accuracy: 0.0000e+00
# Epoch 352/2000
#  - 0s - loss: -1.0828e+01 - categorical_accuracy: 0.0000e+00
# Epoch 353/2000
#  - 0s - loss: -1.0830e+01 - categorical_accuracy: 0.0000e+00
# Epoch 354/2000
#  - 0s - loss: -1.0832e+01 - categorical_accuracy: 0.0000e+00
# Epoch 355/2000
#  - 0s - loss: -1.0834e+01 - categorical_accuracy: 0.0000e+00
# Epoch 356/2000
#  - 0s - loss: -1.0836e+01 - categorical_accuracy: 0.0000e+00
# Epoch 357/2000
#  - 0s - loss: -1.0837e+01 - categorical_accuracy: 0.0000e+00
# Epoch 358/2000
#  - 0s - loss: -1.0839e+01 - categorical_accuracy: 0.0000e+00
# Epoch 359/2000
#  - 0s - loss: -1.0841e+01 - categorical_accuracy: 0.0000e+00
# Epoch 360/2000
#  - 0s - loss: -1.0842e+01 - categorical_accuracy: 0.0000e+00
# Epoch 361/2000
#  - 0s - loss: -1.0845e+01 - categorical_accuracy: 0.0000e+00
# Epoch 362/2000
#  - 0s - loss: -1.0847e+01 - categorical_accuracy: 0.0000e+00
# Epoch 363/2000
#  - 0s - loss: -1.0848e+01 - categorical_accuracy: 0.0000e+00
# Epoch 364/2000
#  - 0s - loss: -1.0851e+01 - categorical_accuracy: 0.0000e+00
# Epoch 365/2000
#  - 0s - loss: -1.0852e+01 - categorical_accuracy: 0.0000e+00
# Epoch 366/2000
#  - 0s - loss: -1.0854e+01 - categorical_accuracy: 0.0000e+00
# Epoch 367/2000
#  - 0s - loss: -1.0857e+01 - categorical_accuracy: 0.0000e+00
# Epoch 368/2000
#  - 0s - loss: -1.0858e+01 - categorical_accuracy: 0.0000e+00
# Epoch 369/2000
#  - 0s - loss: -1.0860e+01 - categorical_accuracy: 0.0000e+00
# Epoch 370/2000
#  - 0s - loss: -1.0861e+01 - categorical_accuracy: 0.0000e+00
# Epoch 371/2000
#  - 0s - loss: -1.0863e+01 - categorical_accuracy: 0.0000e+00
# Epoch 372/2000
#  - 0s - loss: -1.0865e+01 - categorical_accuracy: 0.0000e+00
# Epoch 373/2000
#  - 0s - loss: -1.0867e+01 - categorical_accuracy: 0.0000e+00
# Epoch 374/2000
#  - 0s - loss: -1.0868e+01 - categorical_accuracy: 0.0000e+00
# Epoch 375/2000
#  - 0s - loss: -1.0870e+01 - categorical_accuracy: 0.0000e+00
# Epoch 376/2000
#  - 0s - loss: -1.0872e+01 - categorical_accuracy: 0.0000e+00
# Epoch 377/2000
#  - 0s - loss: -1.0874e+01 - categorical_accuracy: 0.0000e+00
# Epoch 378/2000
#  - 0s - loss: -1.0876e+01 - categorical_accuracy: 0.0000e+00
# Epoch 379/2000
#  - 0s - loss: -1.0878e+01 - categorical_accuracy: 0.0000e+00
# Epoch 380/2000
#  - 0s - loss: -1.0880e+01 - categorical_accuracy: 0.0000e+00
# Epoch 381/2000
#  - 0s - loss: -1.0881e+01 - categorical_accuracy: 0.0000e+00
# Epoch 382/2000
#  - 0s - loss: -1.0883e+01 - categorical_accuracy: 0.0000e+00
# Epoch 383/2000
#  - 0s - loss: -1.0885e+01 - categorical_accuracy: 0.0000e+00
# Epoch 384/2000
#  - 0s - loss: -1.0887e+01 - categorical_accuracy: 0.0000e+00
# Epoch 385/2000
#  - 0s - loss: -1.0889e+01 - categorical_accuracy: 0.0000e+00
# Epoch 386/2000
#  - 0s - loss: -1.0891e+01 - categorical_accuracy: 0.0000e+00
# Epoch 387/2000
#  - 0s - loss: -1.0893e+01 - categorical_accuracy: 0.0000e+00
# Epoch 388/2000
#  - 0s - loss: -1.0894e+01 - categorical_accuracy: 0.0000e+00
# Epoch 389/2000
#  - 0s - loss: -1.0896e+01 - categorical_accuracy: 0.0000e+00
# Epoch 390/2000
#  - 0s - loss: -1.0898e+01 - categorical_accuracy: 0.0000e+00
# Epoch 391/2000
#  - 0s - loss: -1.0900e+01 - categorical_accuracy: 0.0000e+00
# Epoch 392/2000
#  - 0s - loss: -1.0902e+01 - categorical_accuracy: 0.0000e+00
# Epoch 393/2000
#  - 0s - loss: -1.0904e+01 - categorical_accuracy: 0.0000e+00
# Epoch 394/2000
#  - 0s - loss: -1.0906e+01 - categorical_accuracy: 0.0000e+00
# Epoch 395/2000
#  - 0s - loss: -1.0908e+01 - categorical_accuracy: 0.0000e+00
# Epoch 396/2000
#  - 0s - loss: -1.0910e+01 - categorical_accuracy: 0.0000e+00
# Epoch 397/2000
#  - 0s - loss: -1.0911e+01 - categorical_accuracy: 0.0000e+00
# Epoch 398/2000
#  - 0s - loss: -1.0913e+01 - categorical_accuracy: 0.0000e+00
# Epoch 399/2000
#  - 0s - loss: -1.0914e+01 - categorical_accuracy: 0.0000e+00
# Epoch 400/2000
#  - 0s - loss: -1.0917e+01 - categorical_accuracy: 0.0000e+00
# Epoch 401/2000
#  - 0s - loss: -1.0919e+01 - categorical_accuracy: 0.0000e+00
# Epoch 402/2000
#  - 0s - loss: -1.0921e+01 - categorical_accuracy: 0.0000e+00
# Epoch 403/2000
#  - 0s - loss: -1.0922e+01 - categorical_accuracy: 0.0000e+00
# Epoch 404/2000
#  - 0s - loss: -1.0924e+01 - categorical_accuracy: 0.0000e+00
# Epoch 405/2000
#  - 0s - loss: -1.0926e+01 - categorical_accuracy: 0.0000e+00
# Epoch 406/2000
#  - 0s - loss: -1.0928e+01 - categorical_accuracy: 0.0000e+00
# Epoch 407/2000
#  - 0s - loss: -1.0930e+01 - categorical_accuracy: 0.0000e+00
# Epoch 408/2000
#  - 0s - loss: -1.0931e+01 - categorical_accuracy: 0.0000e+00
# Epoch 409/2000
#  - 0s - loss: -1.0934e+01 - categorical_accuracy: 0.0000e+00
# Epoch 410/2000
#  - 0s - loss: -1.0936e+01 - categorical_accuracy: 0.0000e+00
# Epoch 411/2000
#  - 0s - loss: -1.0938e+01 - categorical_accuracy: 0.0000e+00
# Epoch 412/2000
#  - 0s - loss: -1.0940e+01 - categorical_accuracy: 0.0000e+00
# Epoch 413/2000
#  - 0s - loss: -1.0941e+01 - categorical_accuracy: 0.0000e+00
# Epoch 414/2000
#  - 0s - loss: -1.0943e+01 - categorical_accuracy: 0.0000e+00
# Epoch 415/2000
#  - 0s - loss: -1.0945e+01 - categorical_accuracy: 0.0000e+00
# Epoch 416/2000
#  - 0s - loss: -1.0947e+01 - categorical_accuracy: 0.0000e+00
# Epoch 417/2000
#  - 0s - loss: -1.0949e+01 - categorical_accuracy: 0.0000e+00
# Epoch 418/2000
#  - 0s - loss: -1.0951e+01 - categorical_accuracy: 0.0000e+00
# Epoch 419/2000
#  - 0s - loss: -1.0952e+01 - categorical_accuracy: 0.0000e+00
# Epoch 420/2000
#  - 0s - loss: -1.0955e+01 - categorical_accuracy: 0.0000e+00
# Epoch 421/2000
#  - 0s - loss: -1.0957e+01 - categorical_accuracy: 0.0000e+00
# Epoch 422/2000
#  - 0s - loss: -1.0958e+01 - categorical_accuracy: 0.0000e+00
# Epoch 423/2000
#  - 0s - loss: -1.0960e+01 - categorical_accuracy: 0.0000e+00
# Epoch 424/2000
#  - 0s - loss: -1.0961e+01 - categorical_accuracy: 0.0000e+00
# Epoch 425/2000
#  - 0s - loss: -1.0964e+01 - categorical_accuracy: 0.0000e+00
# Epoch 426/2000
#  - 0s - loss: -1.0966e+01 - categorical_accuracy: 0.0000e+00
# Epoch 427/2000
#  - 0s - loss: -1.0967e+01 - categorical_accuracy: 0.0000e+00
# Epoch 428/2000
#  - 0s - loss: -1.0970e+01 - categorical_accuracy: 0.0000e+00
# Epoch 429/2000
#  - 0s - loss: -1.0972e+01 - categorical_accuracy: 0.0000e+00
# Epoch 430/2000
#  - 0s - loss: -1.0974e+01 - categorical_accuracy: 0.0000e+00
# Epoch 431/2000
#  - 0s - loss: -1.0975e+01 - categorical_accuracy: 0.0000e+00
# Epoch 432/2000
#  - 0s - loss: -1.0977e+01 - categorical_accuracy: 0.0000e+00
# Epoch 433/2000
#  - 0s - loss: -1.0978e+01 - categorical_accuracy: 0.0000e+00
# Epoch 434/2000
#  - 0s - loss: -1.0980e+01 - categorical_accuracy: 0.0000e+00
# Epoch 435/2000
#  - 0s - loss: -1.0982e+01 - categorical_accuracy: 0.0000e+00
# Epoch 436/2000
#  - 0s - loss: -1.0985e+01 - categorical_accuracy: 0.0000e+00
# Epoch 437/2000
#  - 0s - loss: -1.0987e+01 - categorical_accuracy: 0.0000e+00
# Epoch 438/2000
#  - 0s - loss: -1.0989e+01 - categorical_accuracy: 0.0000e+00
# Epoch 439/2000
#  - 0s - loss: -1.0990e+01 - categorical_accuracy: 0.0000e+00
# Epoch 440/2000
#  - 0s - loss: -1.0991e+01 - categorical_accuracy: 0.0000e+00
# Epoch 441/2000
#  - 0s - loss: -1.0994e+01 - categorical_accuracy: 0.0000e+00
# Epoch 442/2000
#  - 0s - loss: -1.0996e+01 - categorical_accuracy: 0.0000e+00
# Epoch 443/2000
#  - 0s - loss: -1.0997e+01 - categorical_accuracy: 0.0000e+00
# Epoch 444/2000
#  - 0s - loss: -1.1000e+01 - categorical_accuracy: 0.0000e+00
# Epoch 445/2000
#  - 0s - loss: -1.1002e+01 - categorical_accuracy: 0.0000e+00
# Epoch 446/2000
#  - 0s - loss: -1.1003e+01 - categorical_accuracy: 0.0000e+00
# Epoch 447/2000
#  - 0s - loss: -1.1005e+01 - categorical_accuracy: 0.0000e+00
# Epoch 448/2000
#  - 0s - loss: -1.1007e+01 - categorical_accuracy: 0.0000e+00
# Epoch 449/2000
#  - 0s - loss: -1.1009e+01 - categorical_accuracy: 0.0000e+00
# Epoch 450/2000
#  - 0s - loss: -1.1011e+01 - categorical_accuracy: 0.0000e+00
# Epoch 451/2000
#  - 0s - loss: -1.1013e+01 - categorical_accuracy: 0.0000e+00
# Epoch 452/2000
#  - 0s - loss: -1.1015e+01 - categorical_accuracy: 0.0000e+00
# Epoch 453/2000
#  - 0s - loss: -1.1016e+01 - categorical_accuracy: 0.0000e+00
# Epoch 454/2000
#  - 0s - loss: -1.1018e+01 - categorical_accuracy: 0.0000e+00
# Epoch 455/2000
#  - 0s - loss: -1.1019e+01 - categorical_accuracy: 0.0000e+00
# Epoch 456/2000
#  - 0s - loss: -1.1021e+01 - categorical_accuracy: 0.0000e+00
# Epoch 457/2000
#  - 0s - loss: -1.1023e+01 - categorical_accuracy: 0.0000e+00
# Epoch 458/2000
#  - 0s - loss: -1.1025e+01 - categorical_accuracy: 0.0000e+00
# Epoch 459/2000
#  - 0s - loss: -1.1027e+01 - categorical_accuracy: 0.0000e+00
# Epoch 460/2000
#  - 0s - loss: -1.1029e+01 - categorical_accuracy: 0.0000e+00
# Epoch 461/2000
#  - 0s - loss: -1.1031e+01 - categorical_accuracy: 0.0000e+00
# Epoch 462/2000
#  - 0s - loss: -1.1031e+01 - categorical_accuracy: 0.0000e+00
# Epoch 463/2000
#  - 0s - loss: -1.1034e+01 - categorical_accuracy: 0.0000e+00
# Epoch 464/2000
#  - 0s - loss: -1.1035e+01 - categorical_accuracy: 0.0000e+00
# Epoch 465/2000
#  - 0s - loss: -1.1038e+01 - categorical_accuracy: 0.0000e+00
# Epoch 466/2000
#  - 0s - loss: -1.1039e+01 - categorical_accuracy: 0.0000e+00
# Epoch 467/2000
#  - 0s - loss: -1.1040e+01 - categorical_accuracy: 0.0000e+00
# Epoch 468/2000
#  - 0s - loss: -1.1042e+01 - categorical_accuracy: 0.0000e+00
# Epoch 469/2000
#  - 0s - loss: -1.1044e+01 - categorical_accuracy: 0.0000e+00
# Epoch 470/2000
#  - 0s - loss: -1.1046e+01 - categorical_accuracy: 0.0000e+00
# Epoch 471/2000
#  - 0s - loss: -1.1047e+01 - categorical_accuracy: 0.0000e+00
# Epoch 472/2000
#  - 0s - loss: -1.1049e+01 - categorical_accuracy: 0.0000e+00
# Epoch 473/2000
#  - 0s - loss: -1.1051e+01 - categorical_accuracy: 0.0000e+00
# Epoch 474/2000
#  - 0s - loss: -1.1053e+01 - categorical_accuracy: 0.0000e+00
# Epoch 475/2000
#  - 0s - loss: -1.1054e+01 - categorical_accuracy: 0.0000e+00
# Epoch 476/2000
#  - 0s - loss: -1.1057e+01 - categorical_accuracy: 0.0000e+00
# Epoch 477/2000
#  - 0s - loss: -1.1058e+01 - categorical_accuracy: 0.0000e+00
# Epoch 478/2000
#  - 0s - loss: -1.1059e+01 - categorical_accuracy: 0.0000e+00
# Epoch 479/2000
#  - 0s - loss: -1.1062e+01 - categorical_accuracy: 0.0000e+00
# Epoch 480/2000
#  - 0s - loss: -1.1063e+01 - categorical_accuracy: 0.0000e+00
# Epoch 481/2000
#  - 0s - loss: -1.1064e+01 - categorical_accuracy: 0.0000e+00
# Epoch 482/2000
#  - 0s - loss: -1.1067e+01 - categorical_accuracy: 0.0000e+00
# Epoch 483/2000
#  - 0s - loss: -1.1069e+01 - categorical_accuracy: 0.0000e+00
# Epoch 484/2000
#  - 0s - loss: -1.1071e+01 - categorical_accuracy: 0.0000e+00
# Epoch 485/2000
#  - 0s - loss: -1.1073e+01 - categorical_accuracy: 0.0000e+00
# Epoch 486/2000
#  - 0s - loss: -1.1075e+01 - categorical_accuracy: 0.0000e+00
# Epoch 487/2000
#  - 0s - loss: -1.1076e+01 - categorical_accuracy: 0.0000e+00
# Epoch 488/2000
#  - 0s - loss: -1.1078e+01 - categorical_accuracy: 0.0000e+00
# Epoch 489/2000
#  - 0s - loss: -1.1079e+01 - categorical_accuracy: 0.0000e+00
# Epoch 490/2000
#  - 0s - loss: -1.1081e+01 - categorical_accuracy: 0.0000e+00
# Epoch 491/2000
#  - 0s - loss: -1.1082e+01 - categorical_accuracy: 0.0000e+00
# Epoch 492/2000
#  - 0s - loss: -1.1085e+01 - categorical_accuracy: 0.0000e+00
# Epoch 493/2000
#  - 0s - loss: -1.1086e+01 - categorical_accuracy: 0.0000e+00
# Epoch 494/2000
#  - 0s - loss: -1.1088e+01 - categorical_accuracy: 0.0000e+00
# Epoch 495/2000
#  - 0s - loss: -1.1089e+01 - categorical_accuracy: 0.0000e+00
# Epoch 496/2000
#  - 0s - loss: -1.1091e+01 - categorical_accuracy: 0.0000e+00
# Epoch 497/2000
#  - 0s - loss: -1.1093e+01 - categorical_accuracy: 0.0000e+00
# Epoch 498/2000
#  - 0s - loss: -1.1095e+01 - categorical_accuracy: 0.0000e+00
# Epoch 499/2000
#  - 0s - loss: -1.1097e+01 - categorical_accuracy: 0.0000e+00
# Epoch 500/2000
#  - 0s - loss: -1.1098e+01 - categorical_accuracy: 0.0000e+00
# Epoch 501/2000
#  - 0s - loss: -1.1100e+01 - categorical_accuracy: 0.0000e+00
# Epoch 502/2000
#  - 0s - loss: -1.1102e+01 - categorical_accuracy: 0.0000e+00
# Epoch 503/2000
#  - 0s - loss: -1.1104e+01 - categorical_accuracy: 0.0000e+00
# Epoch 504/2000
#  - 0s - loss: -1.1105e+01 - categorical_accuracy: 0.0000e+00
# Epoch 505/2000
#  - 0s - loss: -1.1107e+01 - categorical_accuracy: 0.0000e+00
# Epoch 506/2000
#  - 0s - loss: -1.1109e+01 - categorical_accuracy: 0.0000e+00
# Epoch 507/2000
#  - 0s - loss: -1.1111e+01 - categorical_accuracy: 0.0000e+00
# Epoch 508/2000
#  - 0s - loss: -1.1112e+01 - categorical_accuracy: 0.0000e+00
# Epoch 509/2000
#  - 0s - loss: -1.1115e+01 - categorical_accuracy: 0.0000e+00
# Epoch 510/2000
#  - 0s - loss: -1.1116e+01 - categorical_accuracy: 0.0000e+00
# Epoch 511/2000
#  - 0s - loss: -1.1117e+01 - categorical_accuracy: 0.0000e+00
# Epoch 512/2000
#  - 0s - loss: -1.1119e+01 - categorical_accuracy: 0.0000e+00
# Epoch 513/2000
#  - 0s - loss: -1.1121e+01 - categorical_accuracy: 0.0000e+00
# Epoch 514/2000
#  - 0s - loss: -1.1124e+01 - categorical_accuracy: 0.0000e+00
# Epoch 515/2000
#  - 0s - loss: -1.1125e+01 - categorical_accuracy: 0.0000e+00
# Epoch 516/2000
#  - 0s - loss: -1.1127e+01 - categorical_accuracy: 0.0000e+00
# Epoch 517/2000
#  - 0s - loss: -1.1129e+01 - categorical_accuracy: 0.0000e+00
# Epoch 518/2000
#  - 0s - loss: -1.1130e+01 - categorical_accuracy: 0.0000e+00
# Epoch 519/2000
#  - 0s - loss: -1.1132e+01 - categorical_accuracy: 0.0000e+00
# Epoch 520/2000
#  - 0s - loss: -1.1134e+01 - categorical_accuracy: 0.0000e+00
# Epoch 521/2000
#  - 0s - loss: -1.1135e+01 - categorical_accuracy: 0.0000e+00
# Epoch 522/2000
#  - 0s - loss: -1.1137e+01 - categorical_accuracy: 0.0000e+00
# Epoch 523/2000
#  - 0s - loss: -1.1138e+01 - categorical_accuracy: 0.0000e+00
# Epoch 524/2000
#  - 0s - loss: -1.1140e+01 - categorical_accuracy: 0.0000e+00
# Epoch 525/2000
#  - 0s - loss: -1.1142e+01 - categorical_accuracy: 0.0000e+00
# Epoch 526/2000
#  - 0s - loss: -1.1144e+01 - categorical_accuracy: 0.0000e+00
# Epoch 527/2000
#  - 0s - loss: -1.1146e+01 - categorical_accuracy: 0.0000e+00
# Epoch 528/2000
#  - 0s - loss: -1.1148e+01 - categorical_accuracy: 0.0000e+00
# Epoch 529/2000
#  - 0s - loss: -1.1149e+01 - categorical_accuracy: 0.0000e+00
# Epoch 530/2000
#  - 0s - loss: -1.1151e+01 - categorical_accuracy: 0.0000e+00
# Epoch 531/2000
#  - 0s - loss: -1.1153e+01 - categorical_accuracy: 0.0000e+00
# Epoch 532/2000
#  - 0s - loss: -1.1155e+01 - categorical_accuracy: 0.0000e+00
# Epoch 533/2000
#  - 0s - loss: -1.1156e+01 - categorical_accuracy: 0.0000e+00
# Epoch 534/2000
#  - 0s - loss: -1.1159e+01 - categorical_accuracy: 0.0000e+00
# Epoch 535/2000
#  - 0s - loss: -1.1160e+01 - categorical_accuracy: 0.0000e+00
# Epoch 536/2000
#  - 0s - loss: -1.1162e+01 - categorical_accuracy: 0.0000e+00
# Epoch 537/2000
#  - 0s - loss: -1.1164e+01 - categorical_accuracy: 0.0000e+00
# Epoch 538/2000
#  - 0s - loss: -1.1166e+01 - categorical_accuracy: 0.0000e+00
# Epoch 539/2000
#  - 0s - loss: -1.1167e+01 - categorical_accuracy: 0.0000e+00
# Epoch 540/2000
#  - 0s - loss: -1.1170e+01 - categorical_accuracy: 0.0000e+00
# Epoch 541/2000
#  - 0s - loss: -1.1171e+01 - categorical_accuracy: 0.0000e+00
# Epoch 542/2000
#  - 0s - loss: -1.1173e+01 - categorical_accuracy: 0.0000e+00
# Epoch 543/2000
#  - 0s - loss: -1.1175e+01 - categorical_accuracy: 0.0000e+00
# Epoch 544/2000
#  - 0s - loss: -1.1177e+01 - categorical_accuracy: 0.0000e+00
# Epoch 545/2000
#  - 0s - loss: -1.1179e+01 - categorical_accuracy: 0.0000e+00
# Epoch 546/2000
#  - 0s - loss: -1.1181e+01 - categorical_accuracy: 0.0000e+00
# Epoch 547/2000
#  - 0s - loss: -1.1182e+01 - categorical_accuracy: 0.0000e+00
# Epoch 548/2000
#  - 0s - loss: -1.1184e+01 - categorical_accuracy: 0.0000e+00
# Epoch 549/2000
#  - 0s - loss: -1.1186e+01 - categorical_accuracy: 0.0000e+00
# Epoch 550/2000
#  - 0s - loss: -1.1187e+01 - categorical_accuracy: 0.0000e+00
# Epoch 551/2000
#  - 0s - loss: -1.1189e+01 - categorical_accuracy: 0.0000e+00
# Epoch 552/2000
#  - 0s - loss: -1.1191e+01 - categorical_accuracy: 0.0000e+00
# Epoch 553/2000
#  - 0s - loss: -1.1193e+01 - categorical_accuracy: 0.0000e+00
# Epoch 554/2000
#  - 0s - loss: -1.1194e+01 - categorical_accuracy: 0.0000e+00
# Epoch 555/2000
#  - 0s - loss: -1.1196e+01 - categorical_accuracy: 0.0000e+00
# Epoch 556/2000
#  - 0s - loss: -1.1198e+01 - categorical_accuracy: 0.0000e+00
# Epoch 557/2000
#  - 0s - loss: -1.1200e+01 - categorical_accuracy: 0.0000e+00
# Epoch 558/2000
#  - 0s - loss: -1.1202e+01 - categorical_accuracy: 0.0000e+00
# Epoch 559/2000
#  - 0s - loss: -1.1203e+01 - categorical_accuracy: 0.0000e+00
# Epoch 560/2000
#  - 0s - loss: -1.1206e+01 - categorical_accuracy: 0.0000e+00
# Epoch 561/2000
#  - 0s - loss: -1.1207e+01 - categorical_accuracy: 0.0000e+00
# Epoch 562/2000
#  - 0s - loss: -1.1209e+01 - categorical_accuracy: 0.0000e+00
# Epoch 563/2000
#  - 0s - loss: -1.1211e+01 - categorical_accuracy: 0.0000e+00
# Epoch 564/2000
#  - 0s - loss: -1.1213e+01 - categorical_accuracy: 0.0000e+00
# Epoch 565/2000
#  - 0s - loss: -1.1215e+01 - categorical_accuracy: 0.0000e+00
# Epoch 566/2000
#  - 0s - loss: -1.1217e+01 - categorical_accuracy: 0.0000e+00
# Epoch 567/2000
#  - 0s - loss: -1.1219e+01 - categorical_accuracy: 0.0000e+00
# Epoch 568/2000
#  - 0s - loss: -1.1221e+01 - categorical_accuracy: 0.0000e+00
# Epoch 569/2000
#  - 0s - loss: -1.1222e+01 - categorical_accuracy: 0.0000e+00
# Epoch 570/2000
#  - 0s - loss: -1.1224e+01 - categorical_accuracy: 0.0000e+00
# Epoch 571/2000
#  - 0s - loss: -1.1226e+01 - categorical_accuracy: 0.0000e+00
# Epoch 572/2000
#  - 0s - loss: -1.1227e+01 - categorical_accuracy: 0.0000e+00
# Epoch 573/2000
#  - 0s - loss: -1.1229e+01 - categorical_accuracy: 0.0000e+00
# Epoch 574/2000
#  - 0s - loss: -1.1232e+01 - categorical_accuracy: 0.0000e+00
# Epoch 575/2000
#  - 0s - loss: -1.1233e+01 - categorical_accuracy: 0.0000e+00
# Epoch 576/2000
#  - 0s - loss: -1.1235e+01 - categorical_accuracy: 0.0000e+00
# Epoch 577/2000
#  - 0s - loss: -1.1237e+01 - categorical_accuracy: 0.0000e+00
# Epoch 578/2000
#  - 0s - loss: -1.1238e+01 - categorical_accuracy: 0.0000e+00
# Epoch 579/2000
#  - 0s - loss: -1.1241e+01 - categorical_accuracy: 0.0000e+00
# Epoch 580/2000
#  - 0s - loss: -1.1242e+01 - categorical_accuracy: 0.0000e+00
# Epoch 581/2000
#  - 0s - loss: -1.1244e+01 - categorical_accuracy: 0.0000e+00
# Epoch 582/2000
#  - 0s - loss: -1.1245e+01 - categorical_accuracy: 0.0000e+00
# Epoch 583/2000
#  - 0s - loss: -1.1248e+01 - categorical_accuracy: 0.0000e+00
# Epoch 584/2000
#  - 0s - loss: -1.1249e+01 - categorical_accuracy: 0.0000e+00
# Epoch 585/2000
#  - 0s - loss: -1.1251e+01 - categorical_accuracy: 0.0000e+00
# Epoch 586/2000
#  - 0s - loss: -1.1252e+01 - categorical_accuracy: 0.0000e+00
# Epoch 587/2000
#  - 0s - loss: -1.1254e+01 - categorical_accuracy: 0.0000e+00
# Epoch 588/2000
#  - 0s - loss: -1.1256e+01 - categorical_accuracy: 0.0000e+00
# Epoch 589/2000
#  - 0s - loss: -1.1258e+01 - categorical_accuracy: 0.0000e+00
# Epoch 590/2000
#  - 0s - loss: -1.1259e+01 - categorical_accuracy: 0.0000e+00
# Epoch 591/2000
#  - 0s - loss: -1.1261e+01 - categorical_accuracy: 0.0000e+00
# Epoch 592/2000
#  - 0s - loss: -1.1262e+01 - categorical_accuracy: 0.0000e+00
# Epoch 593/2000
#  - 0s - loss: -1.1264e+01 - categorical_accuracy: 0.0000e+00
# Epoch 594/2000
#  - 0s - loss: -1.1267e+01 - categorical_accuracy: 0.0000e+00
# Epoch 595/2000
#  - 0s - loss: -1.1268e+01 - categorical_accuracy: 0.0000e+00
# Epoch 596/2000
#  - 0s - loss: -1.1270e+01 - categorical_accuracy: 0.0000e+00
# Epoch 597/2000
#  - 0s - loss: -1.1271e+01 - categorical_accuracy: 0.0000e+00
# Epoch 598/2000
#  - 0s - loss: -1.1274e+01 - categorical_accuracy: 0.0000e+00
# Epoch 599/2000
#  - 0s - loss: -1.1275e+01 - categorical_accuracy: 0.0000e+00
# Epoch 600/2000
#  - 0s - loss: -1.1277e+01 - categorical_accuracy: 0.0000e+00
# Epoch 601/2000
#  - 0s - loss: -1.1278e+01 - categorical_accuracy: 0.0000e+00
# Epoch 602/2000
#  - 0s - loss: -1.1279e+01 - categorical_accuracy: 0.0000e+00
# Epoch 603/2000
#  - 0s - loss: -1.1282e+01 - categorical_accuracy: 0.0000e+00
# Epoch 604/2000
#  - 0s - loss: -1.1283e+01 - categorical_accuracy: 0.0000e+00
# Epoch 605/2000
#  - 0s - loss: -1.1285e+01 - categorical_accuracy: 0.0000e+00
# Epoch 606/2000
#  - 0s - loss: -1.1287e+01 - categorical_accuracy: 0.0000e+00
# Epoch 607/2000
#  - 0s - loss: -1.1289e+01 - categorical_accuracy: 0.0000e+00
# Epoch 608/2000
#  - 0s - loss: -1.1290e+01 - categorical_accuracy: 0.0000e+00
# Epoch 609/2000
#  - 0s - loss: -1.1292e+01 - categorical_accuracy: 0.0000e+00
# Epoch 610/2000
#  - 0s - loss: -1.1293e+01 - categorical_accuracy: 0.0000e+00
# Epoch 611/2000
#  - 0s - loss: -1.1295e+01 - categorical_accuracy: 0.0000e+00
# Epoch 612/2000
#  - 0s - loss: -1.1297e+01 - categorical_accuracy: 0.0000e+00
# Epoch 613/2000
#  - 0s - loss: -1.1299e+01 - categorical_accuracy: 0.0000e+00
# Epoch 614/2000
#  - 0s - loss: -1.1300e+01 - categorical_accuracy: 0.0000e+00
# Epoch 615/2000
#  - 0s - loss: -1.1302e+01 - categorical_accuracy: 0.0000e+00
# Epoch 616/2000
#  - 0s - loss: -1.1304e+01 - categorical_accuracy: 0.0000e+00
# Epoch 617/2000
#  - 0s - loss: -1.1306e+01 - categorical_accuracy: 0.0000e+00
# Epoch 618/2000
#  - 0s - loss: -1.1307e+01 - categorical_accuracy: 0.0000e+00
# Epoch 619/2000
#  - 0s - loss: -1.1308e+01 - categorical_accuracy: 0.0000e+00
# Epoch 620/2000
#  - 0s - loss: -1.1310e+01 - categorical_accuracy: 0.0000e+00
# Epoch 621/2000
#  - 0s - loss: -1.1312e+01 - categorical_accuracy: 0.0000e+00
# Epoch 622/2000
#  - 0s - loss: -1.1314e+01 - categorical_accuracy: 0.0000e+00
# Epoch 623/2000
#  - 0s - loss: -1.1316e+01 - categorical_accuracy: 0.0000e+00
# Epoch 624/2000
#  - 0s - loss: -1.1317e+01 - categorical_accuracy: 0.0000e+00
# Epoch 625/2000
#  - 0s - loss: -1.1318e+01 - categorical_accuracy: 0.0000e+00
# Epoch 626/2000
#  - 0s - loss: -1.1320e+01 - categorical_accuracy: 0.0000e+00
# Epoch 627/2000
#  - 0s - loss: -1.1322e+01 - categorical_accuracy: 0.0000e+00
# Epoch 628/2000
#  - 0s - loss: -1.1323e+01 - categorical_accuracy: 0.0000e+00
# Epoch 629/2000
#  - 0s - loss: -1.1324e+01 - categorical_accuracy: 0.0000e+00
# Epoch 630/2000
#  - 0s - loss: -1.1327e+01 - categorical_accuracy: 0.0000e+00
# Epoch 631/2000
#  - 0s - loss: -1.1329e+01 - categorical_accuracy: 0.0000e+00
# Epoch 632/2000
# ...
#  - 0s - loss: -1.2546e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1794/2000
#  - 0s - loss: -1.2546e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1795/2000
#  - 0s - loss: -1.2547e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1796/2000
#  - 0s - loss: -1.2548e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1797/2000
#  - 0s - loss: -1.2549e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1798/2000
#  - 0s - loss: -1.2550e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1799/2000
#  - 0s - loss: -1.2551e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1800/2000
#  - 0s - loss: -1.2551e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1801/2000
#  - 0s - loss: -1.2551e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1802/2000
#  - 0s - loss: -1.2551e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1803/2000
#  - 0s - loss: -1.2553e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1804/2000
#  - 0s - loss: -1.2553e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1805/2000
#  - 0s - loss: -1.2554e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1806/2000
#  - 0s - loss: -1.2554e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1807/2000
#  - 0s - loss: -1.2555e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1808/2000
#  - 0s - loss: -1.2555e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1809/2000
#  - 0s - loss: -1.2555e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1810/2000
#  - 0s - loss: -1.2555e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1811/2000
#  - 0s - loss: -1.2556e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1812/2000
#  - 0s - loss: -1.2557e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1813/2000
#  - 0s - loss: -1.2557e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1814/2000
#  - 0s - loss: -1.2558e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1815/2000
#  - 0s - loss: -1.2559e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1816/2000
#  - 0s - loss: -1.2560e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1817/2000
#  - 0s - loss: -1.2560e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1818/2000
#  - 0s - loss: -1.2561e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1819/2000
#  - 0s - loss: -1.2562e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1820/2000
#  - 0s - loss: -1.2563e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1821/2000
#  - 0s - loss: -1.2563e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1822/2000
#  - 0s - loss: -1.2564e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1823/2000
#  - 0s - loss: -1.2564e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1824/2000
#  - 0s - loss: -1.2565e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1825/2000
#  - 0s - loss: -1.2565e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1826/2000
#  - 1s - loss: -1.2566e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1827/2000
#  - 1s - loss: -1.2567e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1828/2000
#  - 1s - loss: -1.2567e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1829/2000
#  - 1s - loss: -1.2567e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1830/2000
#  - 1s - loss: -1.2566e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1831/2000
#  - 1s - loss: -1.2568e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1832/2000
#  - 1s - loss: -1.2569e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1833/2000
#  - 1s - loss: -1.2569e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1834/2000
#  - 1s - loss: -1.2570e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1835/2000
#  - 1s - loss: -1.2571e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1836/2000
#  - 1s - loss: -1.2571e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1837/2000
#  - 1s - loss: -1.2572e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1838/2000
#  - 1s - loss: -1.2572e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1839/2000
#  - 1s - loss: -1.2573e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1840/2000
#  - 1s - loss: -1.2573e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1841/2000
#  - 1s - loss: -1.2573e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1842/2000
#  - 1s - loss: -1.2575e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1843/2000
#  - 1s - loss: -1.2575e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1844/2000
#  - 1s - loss: -1.2576e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1845/2000
#  - 1s - loss: -1.2576e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1846/2000
#  - 1s - loss: -1.2577e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1847/2000
#  - 1s - loss: -1.2578e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1848/2000
#  - 1s - loss: -1.2578e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1849/2000
#  - 1s - loss: -1.2578e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1850/2000
#  - 1s - loss: -1.2579e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1851/2000
#  - 1s - loss: -1.2579e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1852/2000
#  - 1s - loss: -1.2580e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1853/2000
#  - 1s - loss: -1.2580e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1854/2000
#  - 1s - loss: -1.2581e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1855/2000
#  - 1s - loss: -1.2582e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1856/2000
#  - 1s - loss: -1.2583e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1857/2000
#  - 1s - loss: -1.2583e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1858/2000
#  - 1s - loss: -1.2583e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1859/2000
#  - 1s - loss: -1.2584e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1860/2000
#  - 1s - loss: -1.2585e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1861/2000
#  - 1s - loss: -1.2585e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1862/2000
#  - 1s - loss: -1.2586e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1863/2000
#  - 1s - loss: -1.2587e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1864/2000
#  - 1s - loss: -1.2588e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1865/2000
#  - 1s - loss: -1.2588e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1866/2000
#  - 1s - loss: -1.2588e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1867/2000
#  - 1s - loss: -1.2588e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1868/2000
#  - 1s - loss: -1.2588e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1869/2000
#  - 1s - loss: -1.2589e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1870/2000
#  - 1s - loss: -1.2590e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1871/2000
#  - 1s - loss: -1.2590e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1872/2000
#  - 1s - loss: -1.2591e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1873/2000
#  - 1s - loss: -1.2591e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1874/2000
#  - 1s - loss: -1.2592e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1875/2000
#  - 1s - loss: -1.2593e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1876/2000
#  - 1s - loss: -1.2594e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1877/2000
#  - 1s - loss: -1.2594e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1878/2000
#  - 1s - loss: -1.2595e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1879/2000
#  - 1s - loss: -1.2595e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1880/2000
#  - 1s - loss: -1.2595e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1881/2000
#  - 1s - loss: -1.2596e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1882/2000
#  - 1s - loss: -1.2596e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1883/2000
#  - 1s - loss: -1.2597e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1884/2000
#  - 1s - loss: -1.2599e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1885/2000
#  - 1s - loss: -1.2599e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1886/2000
#  - 1s - loss: -1.2599e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1887/2000
#  - 1s - loss: -1.2600e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1888/2000
#  - 1s - loss: -1.2600e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1889/2000
#  - 1s - loss: -1.2601e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1890/2000
#  - 1s - loss: -1.2601e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1891/2000
#  - 1s - loss: -1.2602e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1892/2000
#  - 1s - loss: -1.2603e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1893/2000
#  - 1s - loss: -1.2603e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1894/2000
#  - 1s - loss: -1.2604e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1895/2000
#  - 1s - loss: -1.2604e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1896/2000
#  - 1s - loss: -1.2604e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1897/2000
#  - 1s - loss: -1.2605e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1898/2000
#  - 1s - loss: -1.2605e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1899/2000
#  - 1s - loss: -1.2606e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1900/2000
#  - 1s - loss: -1.2606e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1901/2000
#  - 1s - loss: -1.2607e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1902/2000
#  - 1s - loss: -1.2607e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1903/2000
#  - 1s - loss: -1.2608e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1904/2000
#  - 1s - loss: -1.2609e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1905/2000
#  - 1s - loss: -1.2609e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1906/2000
#  - 1s - loss: -1.2610e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1907/2000
#  - 1s - loss: -1.2610e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1908/2000
#  - 1s - loss: -1.2611e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1909/2000
#  - 1s - loss: -1.2611e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1910/2000
#  - 1s - loss: -1.2612e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1911/2000
#  - 1s - loss: -1.2613e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1912/2000
#  - 1s - loss: -1.2613e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1913/2000
#  - 1s - loss: -1.2614e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1914/2000
#  - 1s - loss: -1.2615e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1915/2000
#  - 1s - loss: -1.2615e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1916/2000
#  - 1s - loss: -1.2615e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1917/2000
#  - 1s - loss: -1.2615e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1918/2000
#  - 1s - loss: -1.2616e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1919/2000
#  - 1s - loss: -1.2616e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1920/2000
#  - 1s - loss: -1.2617e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1921/2000
#  - 1s - loss: -1.2618e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1922/2000
#  - 1s - loss: -1.2619e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1923/2000
#  - 1s - loss: -1.2619e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1924/2000
#  - 1s - loss: -1.2620e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1925/2000
#  - 1s - loss: -1.2620e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1926/2000
#  - 1s - loss: -1.2621e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1927/2000
#  - 1s - loss: -1.2621e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1928/2000
#  - 1s - loss: -1.2622e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1929/2000
#  - 1s - loss: -1.2622e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1930/2000
#  - 1s - loss: -1.2623e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1931/2000
#  - 1s - loss: -1.2623e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1932/2000
#  - 1s - loss: -1.2624e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1933/2000
#  - 1s - loss: -1.2624e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1934/2000
#  - 1s - loss: -1.2625e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1935/2000
#  - 1s - loss: -1.2626e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1936/2000
#  - 1s - loss: -1.2626e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1937/2000
#  - 1s - loss: -1.2626e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1938/2000
#  - 1s - loss: -1.2627e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1939/2000
#  - 1s - loss: -1.2628e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1940/2000
#  - 1s - loss: -1.2628e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1941/2000
#  - 1s - loss: -1.2628e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1942/2000
#  - 1s - loss: -1.2629e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1943/2000
#  - 1s - loss: -1.2630e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1944/2000
#  - 1s - loss: -1.2630e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1945/2000
#  - 1s - loss: -1.2631e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1946/2000
#  - 1s - loss: -1.2631e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1947/2000
#  - 1s - loss: -1.2631e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1948/2000
#  - 1s - loss: -1.2631e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1949/2000
#  - 1s - loss: -1.2632e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1950/2000
#  - 1s - loss: -1.2633e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1951/2000
#  - 1s - loss: -1.2634e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1952/2000
#  - 1s - loss: -1.2635e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1953/2000
#  - 1s - loss: -1.2635e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1954/2000
#  - 1s - loss: -1.2635e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1955/2000
#  - 1s - loss: -1.2634e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1956/2000
#  - 1s - loss: -1.2636e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1957/2000
#  - 1s - loss: -1.2637e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1958/2000
#  - 1s - loss: -1.2638e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1959/2000
#  - 1s - loss: -1.2638e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1960/2000
#  - 1s - loss: -1.2638e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1961/2000
#  - 1s - loss: -1.2639e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1962/2000
#  - 1s - loss: -1.2640e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1963/2000
#  - 1s - loss: -1.2640e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1964/2000
#  - 1s - loss: -1.2641e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1965/2000
#  - 1s - loss: -1.2641e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1966/2000
#  - 1s - loss: -1.2641e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1967/2000
#  - 1s - loss: -1.2641e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1968/2000
#  - 1s - loss: -1.2643e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1969/2000
#  - 1s - loss: -1.2643e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1970/2000
#  - 1s - loss: -1.2644e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1971/2000
#  - 1s - loss: -1.2645e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1972/2000
#  - 1s - loss: -1.2645e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1973/2000
#  - 1s - loss: -1.2645e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1974/2000
#  - 1s - loss: -1.2646e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1975/2000
#  - 1s - loss: -1.2646e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1976/2000
#  - 1s - loss: -1.2647e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1977/2000
#  - 1s - loss: -1.2647e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1978/2000
#  - 1s - loss: -1.2648e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1979/2000
#  - 1s - loss: -1.2647e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1980/2000
#  - 1s - loss: -1.2648e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1981/2000
#  - 1s - loss: -1.2649e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1982/2000
#  - 1s - loss: -1.2649e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1983/2000
#  - 1s - loss: -1.2650e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1984/2000
#  - 1s - loss: -1.2650e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1985/2000
#  - 1s - loss: -1.2651e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1986/2000
#  - 1s - loss: -1.2651e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1987/2000
#  - 1s - loss: -1.2652e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1988/2000
#  - 1s - loss: -1.2652e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1989/2000
#  - 1s - loss: -1.2653e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1990/2000
#  - 1s - loss: -1.2654e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1991/2000
#  - 1s - loss: -1.2654e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1992/2000
#  - 1s - loss: -1.2655e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1993/2000
#  - 1s - loss: -1.2655e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1994/2000
#  - 1s - loss: -1.2655e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1995/2000
#  - 1s - loss: -1.2655e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1996/2000
#  - 1s - loss: -1.2656e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1997/2000
#  - 1s - loss: -1.2657e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1998/2000
#  - 1s - loss: -1.2658e+01 - categorical_accuracy: 0.0000e+00
# Epoch 1999/2000
#  - 1s - loss: -1.2658e+01 - categorical_accuracy: 0.0000e+00
# Epoch 2000/2000
#  - 1s - loss: -1.2659e+01 - categorical_accuracy: 0.0000e+00

# %%
adversarial_model.load_weights('adversarial_img_weights_untargeted_final.h5')

# %%
adversarial_model.load_weights('adversarial_img_weights_untargeted.h5')

# %%
#Recuperamos los parámetros de la capa de ruido
ruido = adversarial_model.get_weights()[0].reshape((224,224,3))
print('Ruido')
print('Valor absoluto máximo', np.max(np.abs(ruido)))
plotImage(ruido)
imagen_adversarial = x + ruido
print('Imagen original')
plotImage(x[0])
print('Imagen + ruido ')
plotImage(imagen_adversarial[0])
print('Prediccion img original',decode_predictions(model.predict(x), top=3)[0] )
pred_advs = model.predict(imagen_adversarial)[0]
print(pred_advs[target])
print('Predicción img adversarial',decode_predictions(model.predict(imagen_adversarial), top=3)[0])
print(clasifica_mod_adversarial({'image':x,'unity':np.ones(shape=(1,1))}, adversarial_model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Ruido
# Valor absoluto máximo 27.507566
# Imagen original
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Imagen + ruido
# Prediccion img original [('n02504458', 'African_elephant', 0.86625427), ('n02504013', 'Indian_elephant', 0.06860924), ('n01871265', 'tusker', 0.06478469)]
# 0.78276473
# Predicción img adversarial [('n02504458', 'African_elephant', 0.78276473), ('n01871265', 'tusker', 0.13702771), ('n02504013', 'Indian_elephant', 0.0794206)]
# [('n02504458', 'African_elephant', 0.78276473), ('n01871265', 'tusker', 0.13702771), ('n02504013', 'Indian_elephant', 0.0794206)]

# %%
#adversarial_model.summary()
#np.save('imagen_adversarial_resnet', imagen_adversarial)
c = np.load('imagen_adversarial_resnet.npy')
#np.save('ruido_adversarial',ruido)
r = np.load('ruido_adversarial.npy')
plotImage(r)
print(decode_predictions(model.predict(c), top=3)[0])
plotImage(c[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [('n02504458', 'African_elephant', 0.86655), ('n02504013', 'Indian_elephant', 0.06839117), ('n01871265', 'tusker', 0.06470819)]

# %%
target_vector = np.zeros((1,1000))
target_vector[0,4] = 1
pred = model.predict(x)
print(np.argmax(pred))
print(np.argmax(target_vector))
print(adversarial_model.evaluate({'image':x,'unity':np.ones(shape=(1,1))}, target_vector))
