# %% [markdown]
# # Creación de un ejemplo adversarial

# %%
import keras
from keras.datasets import mnist
from keras.models import Model
from keras.layers import Dense, Dropout, Flatten ,Input
from keras.layers import Conv2D, MaxPooling2D, Reshape, Add
from keras.metrics import categorical_accuracy
from keras.regularizers import l1_l2, l2, l1
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
from tensorflow.python.keras import backend as K
from keras.preprocessing.image import array_to_img,img_to_array

import matplotlib.pyplot as plt
import numpy as np

from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
##Funciones auxiliares
def plotImage( img, dims = False ):
    if not(dims):
        plt.imshow(img, vmin=0., vmax=1.)
    else: 
        plt.imshow(img.reshape(dims), vmin=0., vmax=1.)
    plt.show()
        

model = ResNet50(weights='imagenet')

img_path = 'elephant.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plotImage(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x_not_pre = x
x = preprocess_input(x)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Eligamos una imagen para crear ejemplo adversarial

# %%
#select image to create an adversarial example from
img = x
plt.imshow(img.reshape((224,224,3)),vmin=0., vmax=1.)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Veamos qué clasificacion da el modelo

# %%
preds = model.predict(x)
print(preds.shape)
target = np.zeros((1,1000))
target[0,4] = 1
print('Predicted:', decode_predictions(target, top=3)[0])
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# (1, 1000)
# Predicted: [('n01494475', 'hammerhead', 1.0), ('n15075141', 'toilet_tissue', 0.0), ('n02319095', 'sea_urchin', 0.0)]
# Predicted: [('n02504458', 'African_elephant', 0.86625427), ('n02504013', 'Indian_elephant', 0.06860924), ('n01871265', 'tusker', 0.06478469)]

# %%
#applying random noise does not fool the classifier
#quantized_noise = np.round(np.random.normal(loc=0.0, scale=0.3, size=img.shape) * 255.) / 255.
quantized_noise = np.round(np.random.normal(loc=0.0, scale=0.8, size=x_not_pre.shape) * 255.)
#noisy_img = np.clip(img + quantized_noise, 0., 1.)
#plt.imshow(quantized_noise[0],vmin=0., vmax=1.)
plotImage(x_not_pre[0])
print(x_not_pre[0])
#plt.show()
plotImage(quantized_noise[0])
noisy_img = x_not_pre[0] + quantized_noise[0]
print(noisy_img.shape)
plotImage(noisy_img)
noisy_img_pre = np.expand_dims(noisy_img, axis=0)
noisy_img_pre = preprocess_input(noisy_img_pre)
preds = model.predict(noisy_img_pre)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
#### AQUI HAY ERROR
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [[[  2.3199997  21.221      56.060997 ]
#   [-10.68       10.221001   49.060997 ]
#   [ -9.68       14.221001   57.060997 ]
#   ...
#   [ 87.32       95.221     113.061    ]
#   [ 94.32      102.221     120.061    ]
#   [ 90.32       98.221     116.061    ]]
#
#  [[ -3.6800003  14.221001   49.060997 ]
#   [ -6.6800003  12.221001   51.060997 ]
#   [ -3.6800003  18.221      62.060997 ]
#   ...
#   [ 94.32      100.221     119.061    ]
#   [ 99.32      106.221     127.061    ]
#   [ 86.32       93.221     114.061    ]]
#
#  [[ -9.68        9.221001   46.060997 ]
#   [  2.3199997  23.221      62.060997 ]
#   [-14.68        7.2210007  49.060997 ]
#   ...
#   [101.32      107.221     125.061    ]
#   [ 86.32       96.221     116.061    ]
#   [ 71.32       81.221     101.061    ]]
#
#  ...
#
#  [[-67.68      -77.779     -90.939    ]
#   [-15.68      -32.779     -45.939003 ]
#   [ -7.6800003 -29.779     -46.939003 ]
#   ...
#   [ 32.32       19.221      -2.939003 ]
#   [ 25.32        8.221001  -16.939003 ]
#   [ 36.32       19.221      -5.939003 ]]
#
#  [[ 16.32        8.221001  -11.939003 ]
#   [  5.3199997 -10.778999  -28.939003 ]
#   [ 26.32        4.2210007 -12.939003 ]
#   ...
#   [ 32.32       19.221      -2.939003 ]
#   [ 21.32        5.2210007 -25.939003 ]
#   [ 31.32       15.221001  -15.939003 ]]
#
#  [[ 35.32       30.221       1.060997 ]
#   [ 56.32       37.221      15.060997 ]
#   [ 24.32        5.2210007 -14.939003 ]
#   ...
#   [ 23.32        8.221001  -15.939003 ]
#   [ 42.32       28.221      -1.939003 ]
#   [ 17.32        3.2210007 -26.939003 ]]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (224, 224, 3)
# Predicted: [('n03347037', 'fire_screen', 0.72949594), ('n03000134', 'chainlink_fence', 0.27039608), ('n04332243', 'strainer', 6.967952e-05)]

# %%
#custom activation function for keeping adversarial pixel values between 0.0 and 1.0
def clip(x):
    return K.clip(x, 0.0, 1.0)

#custom loss funciton for non-targeted misclassification
def negative_categorical_crossentropy(yTrue,yPred):
    return 0.0 - K.categorical_crossentropy(yTrue,yPred)

#custom activation to transform image to resnet input format
def preprocessImg(img):
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    return preprocess_input(img)

#add custom objects to dictionary
get_custom_objects().update({'clip': Activation(clip)})
get_custom_objects().update({'negative_categorical_crossentropy': negative_categorical_crossentropy})
get_custom_objects().update({'preprocess': preprocessImg})


def define_adversarial_model(img_shape, regularization, classifier):
    h = img_shape[0]
    w = img_shape[1]
    numChannels = img_shape[2]
    #input for base image
    image = Input(shape=img_shape,name='image')
    #unit input for adversarial noise
    one = Input(shape=(1,),name='unity')
    
    #layer for learning adversarial noise to apply to image
    noise = Dense(h*w*numChannels,activation = None,use_bias=False,kernel_initializer='random_normal',
                  kernel_regularizer=regularization, name='adversarial_noise')(one)
    
    #reshape noise in shape of image
    noise = Reshape(img_shape, name='reshape')(noise)
    
    #add noise to image
    net = Add(name='add')([noise,image])
    #clip values to be within 0.0 and 1.0
    #net = Activation('clip',name='clip_values')(net)
    
    #add preprocess activation
    #net = Activation('preprocess',name='pre_values')(net)
    
    #conecta imagen con ruido adversarial a classificador
    outputs = classifier(net)
    outputs = Reshape((1000,), name='reshape_resnet')(outputs)

    adversarial_model = Model(inputs=[image,one], outputs=outputs)
    #vuelve estáticos los parametros del classificador, solo entrena capa de ruido
    adversarial_model.layers[-1].trainable = False
    return adversarial_model

def entrena_modelo_adversarial(adversarial_model, target, img, num_epocas):
    #target adversarial classification
    #target adversarial classification
    target_vector = np.zeros(1000)
    target_vector[target] = 1.
    
    #callback for saving weights with smallest loss
    checkpoint = ModelCheckpoint('./adversarial_weights_resnet.h5', monitor='loss', verbose=0, save_best_only=True, save_weights_only=True,
                                mode='auto', period=1)
    #train adversarial image
    adversarial_model.fit(x={'image':img,'unity':np.ones(shape=(1,1))},y=target_vector.reshape(1,-1),epochs=num_epocas,verbose=2,
    callbacks=[checkpoint])
    #adversarial_model.fit(x={'image':img,'unity':np.ones(shape=(1,1))},y=target_vector.reshape(1,-1),epochs=num_epocas,verbose=2)
    #restore best weights
    adversarial_model.load_weights('./adversarial_weights_resnet.h5')
    
def recupera_ruido(adversarial_model):
    #quantize adversarial noise
    quantized_weights = np.round(adversarial_model.get_weights()[0].reshape((224,224,3)) * 255.) / 255.
    weights = adversarial_model.get_weights()[0].reshape((224,224,3))
    return weights

def clasifica_resnet(img):
    img = np.expand_dims(img, axis=0)
    img = preprocess_input(img)
    prediccion =  model.predict(img)
    return decode_predictions(prediccion, top=3)[0]
def clasifica_mod_adversarial(inp, net):
    pred =  net.predict(inp)
    return decode_predictions(pred, top=3)[0]
#generate_adversary(x_not_pre,5,model,l1(0.01),'negative_categorical_crossentropy')

# %%
adversarial_model = define_adversarial_model((224,224,3),l1(0.0000001),model)
adversarial_model.compile(optimizer='nadam', loss='categorical_crossentropy', metrics=[categorical_accuracy])

# %%
target = 4
target_vector = np.zeros((1,1000))
target_vector[0, target] = 1
print(decode_predictions(target_vector, top = 3)[0])
entrena_modelo_adversarial(adversarial_model,target,x, 300)
# Out:
# [('n01494475', 'hammerhead', 1.0), ('n15075141', 'toilet_tissue', 0.0), ('n02319095', 'sea_urchin', 0.0)]
# Epoch 1/300
#  - 0s - loss: 5.9919 - categorical_accuracy: 0.0000e+00
# Epoch 2/300
#  - 0s - loss: 5.9836 - categorical_accuracy: 0.0000e+00
# Epoch 3/300
#  - 0s - loss: 5.9753 - categorical_accuracy: 0.0000e+00
# Epoch 4/300
#  - 0s - loss: 5.9671 - categorical_accuracy: 0.0000e+00
# Epoch 5/300
#  - 0s - loss: 5.9587 - categorical_accuracy: 0.0000e+00
# Epoch 6/300
#  - 0s - loss: 5.9504 - categorical_accuracy: 0.0000e+00
# Epoch 7/300
#  - 0s - loss: 5.9421 - categorical_accuracy: 0.0000e+00
# Epoch 8/300
#  - 0s - loss: 5.9339 - categorical_accuracy: 0.0000e+00
# Epoch 9/300
#  - 0s - loss: 5.9258 - categorical_accuracy: 0.0000e+00
# Epoch 10/300
#  - 0s - loss: 5.9179 - categorical_accuracy: 0.0000e+00
# Epoch 11/300
#  - 0s - loss: 5.9099 - categorical_accuracy: 0.0000e+00
# Epoch 12/300
#  - 0s - loss: 5.9020 - categorical_accuracy: 0.0000e+00
# Epoch 13/300
#  - 0s - loss: 5.8942 - categorical_accuracy: 0.0000e+00
# Epoch 14/300
#  - 0s - loss: 5.8863 - categorical_accuracy: 0.0000e+00
# Epoch 15/300
#  - 0s - loss: 5.8785 - categorical_accuracy: 0.0000e+00
# Epoch 16/300
#  - 0s - loss: 5.8708 - categorical_accuracy: 0.0000e+00
# Epoch 17/300
#  - 0s - loss: 5.8632 - categorical_accuracy: 0.0000e+00
# Epoch 18/300
#  - 0s - loss: 5.8556 - categorical_accuracy: 0.0000e+00
# Epoch 19/300
#  - 0s - loss: 5.8480 - categorical_accuracy: 0.0000e+00
# Epoch 20/300
#  - 0s - loss: 5.8406 - categorical_accuracy: 0.0000e+00
# Epoch 21/300
#  - 0s - loss: 5.8332 - categorical_accuracy: 0.0000e+00
# Epoch 22/300
#  - 0s - loss: 5.8257 - categorical_accuracy: 0.0000e+00
# Epoch 23/300
#  - 0s - loss: 5.8183 - categorical_accuracy: 0.0000e+00
# Epoch 24/300
#  - 0s - loss: 5.8110 - categorical_accuracy: 0.0000e+00
# Epoch 25/300
#  - 0s - loss: 5.8038 - categorical_accuracy: 0.0000e+00
# Epoch 26/300
#  - 0s - loss: 5.7965 - categorical_accuracy: 0.0000e+00
# Epoch 27/300
#  - 0s - loss: 5.7894 - categorical_accuracy: 0.0000e+00
# Epoch 28/300
#  - 0s - loss: 5.7824 - categorical_accuracy: 0.0000e+00
# Epoch 29/300
#  - 0s - loss: 5.7753 - categorical_accuracy: 0.0000e+00
# Epoch 30/300
#  - 0s - loss: 5.7682 - categorical_accuracy: 0.0000e+00
# Epoch 31/300
#  - 0s - loss: 5.7612 - categorical_accuracy: 0.0000e+00
# Epoch 32/300
#  - 0s - loss: 5.7542 - categorical_accuracy: 0.0000e+00
# Epoch 33/300
#  - 0s - loss: 5.7474 - categorical_accuracy: 0.0000e+00
# Epoch 34/300
#  - 0s - loss: 5.7405 - categorical_accuracy: 0.0000e+00
# Epoch 35/300
#  - 0s - loss: 5.7337 - categorical_accuracy: 0.0000e+00
# Epoch 36/300
#  - 0s - loss: 5.7270 - categorical_accuracy: 0.0000e+00
# Epoch 37/300
#  - 0s - loss: 5.7203 - categorical_accuracy: 0.0000e+00
# Epoch 38/300
#  - 0s - loss: 5.7136 - categorical_accuracy: 0.0000e+00
# Epoch 39/300
#  - 0s - loss: 5.7068 - categorical_accuracy: 0.0000e+00
# Epoch 40/300
#  - 0s - loss: 5.7002 - categorical_accuracy: 0.0000e+00
# Epoch 41/300
#  - 0s - loss: 5.6936 - categorical_accuracy: 0.0000e+00
# Epoch 42/300
#  - 0s - loss: 5.6869 - categorical_accuracy: 0.0000e+00
# Epoch 43/300
#  - 0s - loss: 5.6803 - categorical_accuracy: 0.0000e+00
# Epoch 44/300
#  - 0s - loss: 5.6735 - categorical_accuracy: 0.0000e+00
# Epoch 45/300
#  - 0s - loss: 5.6668 - categorical_accuracy: 0.0000e+00
# Epoch 46/300
#  - 0s - loss: 5.6601 - categorical_accuracy: 0.0000e+00
# Epoch 47/300
#  - 0s - loss: 5.6534 - categorical_accuracy: 0.0000e+00
# Epoch 48/300
#  - 0s - loss: 5.6465 - categorical_accuracy: 0.0000e+00
# Epoch 49/300
#  - 0s - loss: 5.6396 - categorical_accuracy: 0.0000e+00
# Epoch 50/300
#  - 0s - loss: 5.6327 - categorical_accuracy: 0.0000e+00
# Epoch 51/300
#  - 0s - loss: 5.6259 - categorical_accuracy: 0.0000e+00
# Epoch 52/300
#  - 0s - loss: 5.6192 - categorical_accuracy: 0.0000e+00
# Epoch 53/300
#  - 0s - loss: 5.6126 - categorical_accuracy: 0.0000e+00
# Epoch 54/300
#  - 0s - loss: 5.6061 - categorical_accuracy: 0.0000e+00
# Epoch 55/300
#  - 0s - loss: 5.5997 - categorical_accuracy: 0.0000e+00
# Epoch 56/300
#  - 0s - loss: 5.5933 - categorical_accuracy: 0.0000e+00
# Epoch 57/300
#  - 0s - loss: 5.5869 - categorical_accuracy: 0.0000e+00
# Epoch 58/300
#  - 0s - loss: 5.5806 - categorical_accuracy: 0.0000e+00
# Epoch 59/300
#  - 0s - loss: 5.5744 - categorical_accuracy: 0.0000e+00
# Epoch 60/300
#  - 0s - loss: 5.5682 - categorical_accuracy: 0.0000e+00
# Epoch 61/300
#  - 0s - loss: 5.5620 - categorical_accuracy: 0.0000e+00
# Epoch 62/300
#  - 0s - loss: 5.5557 - categorical_accuracy: 0.0000e+00
# Epoch 63/300
#  - 0s - loss: 5.5495 - categorical_accuracy: 0.0000e+00
# Epoch 64/300
#  - 0s - loss: 5.5432 - categorical_accuracy: 0.0000e+00
# Epoch 65/300
#  - 0s - loss: 5.5370 - categorical_accuracy: 0.0000e+00
# Epoch 66/300
#  - 0s - loss: 5.5308 - categorical_accuracy: 0.0000e+00
# Epoch 67/300
#  - 0s - loss: 5.5246 - categorical_accuracy: 0.0000e+00
# Epoch 68/300
#  - 0s - loss: 5.5184 - categorical_accuracy: 0.0000e+00
# Epoch 69/300
#  - 0s - loss: 5.5122 - categorical_accuracy: 0.0000e+00
# Epoch 70/300
#  - 0s - loss: 5.5060 - categorical_accuracy: 0.0000e+00
# Epoch 71/300
#  - 0s - loss: 5.4999 - categorical_accuracy: 0.0000e+00
# Epoch 72/300
#  - 0s - loss: 5.4937 - categorical_accuracy: 0.0000e+00
# Epoch 73/300
#  - 0s - loss: 5.4875 - categorical_accuracy: 0.0000e+00
# Epoch 74/300
#  - 0s - loss: 5.4813 - categorical_accuracy: 0.0000e+00
# Epoch 75/300
#  - 0s - loss: 5.4751 - categorical_accuracy: 0.0000e+00
# Epoch 76/300
#  - 0s - loss: 5.4689 - categorical_accuracy: 0.0000e+00
# Epoch 77/300
#  - 0s - loss: 5.4626 - categorical_accuracy: 0.0000e+00
# Epoch 78/300
#  - 0s - loss: 5.4563 - categorical_accuracy: 0.0000e+00
# Epoch 79/300
#  - 0s - loss: 5.4500 - categorical_accuracy: 0.0000e+00
# Epoch 80/300
#  - 0s - loss: 5.4437 - categorical_accuracy: 0.0000e+00
# Epoch 81/300
#  - 0s - loss: 5.4375 - categorical_accuracy: 0.0000e+00
# Epoch 82/300
#  - 0s - loss: 5.4312 - categorical_accuracy: 0.0000e+00
# Epoch 83/300
#  - 0s - loss: 5.4249 - categorical_accuracy: 0.0000e+00
# Epoch 84/300
#  - 0s - loss: 5.4186 - categorical_accuracy: 0.0000e+00
# Epoch 85/300
#  - 0s - loss: 5.4123 - categorical_accuracy: 0.0000e+00
# Epoch 86/300
#  - 0s - loss: 5.4061 - categorical_accuracy: 0.0000e+00
# Epoch 87/300
#  - 0s - loss: 5.3999 - categorical_accuracy: 0.0000e+00
# Epoch 88/300
#  - 0s - loss: 5.3936 - categorical_accuracy: 0.0000e+00
# Epoch 89/300
#  - 0s - loss: 5.3873 - categorical_accuracy: 0.0000e+00
# Epoch 90/300
#  - 0s - loss: 5.3809 - categorical_accuracy: 0.0000e+00
# Epoch 91/300
#  - 0s - loss: 5.3746 - categorical_accuracy: 0.0000e+00
# Epoch 92/300
#  - 0s - loss: 5.3682 - categorical_accuracy: 0.0000e+00
# Epoch 93/300
#  - 0s - loss: 5.3619 - categorical_accuracy: 0.0000e+00
# Epoch 94/300
#  - 0s - loss: 5.3556 - categorical_accuracy: 0.0000e+00
# Epoch 95/300
#  - 0s - loss: 5.3493 - categorical_accuracy: 0.0000e+00
# Epoch 96/300
#  - 0s - loss: 5.3429 - categorical_accuracy: 0.0000e+00
# Epoch 97/300
#  - 0s - loss: 5.3367 - categorical_accuracy: 0.0000e+00
# Epoch 98/300
#  - 0s - loss: 5.3303 - categorical_accuracy: 0.0000e+00
# Epoch 99/300
#  - 0s - loss: 5.3240 - categorical_accuracy: 0.0000e+00
# Epoch 100/300
#  - 0s - loss: 5.3177 - categorical_accuracy: 0.0000e+00
# Epoch 101/300
#  - 0s - loss: 5.3114 - categorical_accuracy: 0.0000e+00
# Epoch 102/300
#  - 0s - loss: 5.3050 - categorical_accuracy: 0.0000e+00
# Epoch 103/300
#  - 0s - loss: 5.2986 - categorical_accuracy: 0.0000e+00
# Epoch 104/300
#  - 0s - loss: 5.2921 - categorical_accuracy: 0.0000e+00
# Epoch 105/300
#  - 0s - loss: 5.2857 - categorical_accuracy: 0.0000e+00
# Epoch 106/300
#  - 0s - loss: 5.2793 - categorical_accuracy: 0.0000e+00
# Epoch 107/300
#  - 0s - loss: 5.2728 - categorical_accuracy: 0.0000e+00
# Epoch 108/300
#  - 0s - loss: 5.2663 - categorical_accuracy: 0.0000e+00
# Epoch 109/300
#  - 0s - loss: 5.2598 - categorical_accuracy: 0.0000e+00
# Epoch 110/300
#  - 0s - loss: 5.2534 - categorical_accuracy: 0.0000e+00
# Epoch 111/300
#  - 0s - loss: 5.2469 - categorical_accuracy: 0.0000e+00
# Epoch 112/300
#  - 0s - loss: 5.2405 - categorical_accuracy: 0.0000e+00
# Epoch 113/300
#  - 0s - loss: 5.2339 - categorical_accuracy: 0.0000e+00
# Epoch 114/300
#  - 0s - loss: 5.2275 - categorical_accuracy: 0.0000e+00
# Epoch 115/300
#  - 0s - loss: 5.2209 - categorical_accuracy: 0.0000e+00
# Epoch 116/300
#  - 0s - loss: 5.2145 - categorical_accuracy: 0.0000e+00
# Epoch 117/300
#  - 0s - loss: 5.2080 - categorical_accuracy: 0.0000e+00
# Epoch 118/300
#  - 0s - loss: 5.2016 - categorical_accuracy: 0.0000e+00
# Epoch 119/300
#  - 0s - loss: 5.1953 - categorical_accuracy: 0.0000e+00
# Epoch 120/300
#  - 0s - loss: 5.1889 - categorical_accuracy: 0.0000e+00
# Epoch 121/300
#  - 0s - loss: 5.1825 - categorical_accuracy: 0.0000e+00
# Epoch 122/300
#  - 0s - loss: 5.1762 - categorical_accuracy: 0.0000e+00
# Epoch 123/300
#  - 0s - loss: 5.1699 - categorical_accuracy: 0.0000e+00
# Epoch 124/300
#  - 0s - loss: 5.1635 - categorical_accuracy: 0.0000e+00
# Epoch 125/300
#  - 0s - loss: 5.1572 - categorical_accuracy: 0.0000e+00
# Epoch 126/300
#  - 0s - loss: 5.1510 - categorical_accuracy: 0.0000e+00
# Epoch 127/300
#  - 0s - loss: 5.1448 - categorical_accuracy: 0.0000e+00
# Epoch 128/300
#  - 0s - loss: 5.1386 - categorical_accuracy: 0.0000e+00
# Epoch 129/300
#  - 0s - loss: 5.1324 - categorical_accuracy: 0.0000e+00
# Epoch 130/300
#  - 0s - loss: 5.1262 - categorical_accuracy: 0.0000e+00
# Epoch 131/300
#  - 0s - loss: 5.1202 - categorical_accuracy: 0.0000e+00
# Epoch 132/300
#  - 0s - loss: 5.1141 - categorical_accuracy: 0.0000e+00
# Epoch 133/300
#  - 0s - loss: 5.1081 - categorical_accuracy: 0.0000e+00
# Epoch 134/300
#  - 0s - loss: 5.1020 - categorical_accuracy: 0.0000e+00
# Epoch 135/300
#  - 0s - loss: 5.0959 - categorical_accuracy: 0.0000e+00
# Epoch 136/300
#  - 0s - loss: 5.0897 - categorical_accuracy: 0.0000e+00
# Epoch 137/300
#  - 0s - loss: 5.0836 - categorical_accuracy: 0.0000e+00
# Epoch 138/300
#  - 0s - loss: 5.0776 - categorical_accuracy: 0.0000e+00
# Epoch 139/300
#  - 0s - loss: 5.0715 - categorical_accuracy: 0.0000e+00
# Epoch 140/300
#  - 0s - loss: 5.0655 - categorical_accuracy: 0.0000e+00
# Epoch 141/300
#  - 0s - loss: 5.0596 - categorical_accuracy: 0.0000e+00
# Epoch 142/300
#  - 0s - loss: 5.0537 - categorical_accuracy: 0.0000e+00
# Epoch 143/300
#  - 0s - loss: 5.0479 - categorical_accuracy: 0.0000e+00
# Epoch 144/300
#  - 0s - loss: 5.0422 - categorical_accuracy: 0.0000e+00
# Epoch 145/300
#  - 0s - loss: 5.0365 - categorical_accuracy: 0.0000e+00
# Epoch 146/300
#  - 0s - loss: 5.0308 - categorical_accuracy: 0.0000e+00
# Epoch 147/300
#  - 0s - loss: 5.0250 - categorical_accuracy: 0.0000e+00
# Epoch 148/300
#  - 0s - loss: 5.0193 - categorical_accuracy: 0.0000e+00
# Epoch 149/300
#  - 0s - loss: 5.0135 - categorical_accuracy: 0.0000e+00
# Epoch 150/300
#  - 0s - loss: 5.0078 - categorical_accuracy: 0.0000e+00
# Epoch 151/300
#  - 0s - loss: 5.0020 - categorical_accuracy: 0.0000e+00
# Epoch 152/300
#  - 0s - loss: 4.9962 - categorical_accuracy: 0.0000e+00
# Epoch 153/300
#  - 0s - loss: 4.9905 - categorical_accuracy: 0.0000e+00
# Epoch 154/300
#  - 0s - loss: 4.9847 - categorical_accuracy: 0.0000e+00
# Epoch 155/300
#  - 0s - loss: 4.9788 - categorical_accuracy: 0.0000e+00
# Epoch 156/300
#  - 0s - loss: 4.9730 - categorical_accuracy: 0.0000e+00
# Epoch 157/300
#  - 0s - loss: 4.9671 - categorical_accuracy: 0.0000e+00
# Epoch 158/300
#  - 0s - loss: 4.9613 - categorical_accuracy: 0.0000e+00
# Epoch 159/300
#  - 0s - loss: 4.9553 - categorical_accuracy: 0.0000e+00
# Epoch 160/300
#  - 0s - loss: 4.9494 - categorical_accuracy: 0.0000e+00
# Epoch 161/300
#  - 0s - loss: 4.9435 - categorical_accuracy: 0.0000e+00
# Epoch 162/300
#  - 0s - loss: 4.9376 - categorical_accuracy: 0.0000e+00
# Epoch 163/300
#  - 0s - loss: 4.9318 - categorical_accuracy: 0.0000e+00
# Epoch 164/300
#  - 0s - loss: 4.9260 - categorical_accuracy: 0.0000e+00
# Epoch 165/300
#  - 0s - loss: 4.9202 - categorical_accuracy: 0.0000e+00
# Epoch 166/300
#  - 0s - loss: 4.9143 - categorical_accuracy: 0.0000e+00
# Epoch 167/300
#  - 0s - loss: 4.9086 - categorical_accuracy: 0.0000e+00
# Epoch 168/300
#  - 0s - loss: 4.9028 - categorical_accuracy: 0.0000e+00
# Epoch 169/300
#  - 0s - loss: 4.8970 - categorical_accuracy: 0.0000e+00
# Epoch 170/300
#  - 0s - loss: 4.8912 - categorical_accuracy: 0.0000e+00
# Epoch 171/300
#  - 0s - loss: 4.8855 - categorical_accuracy: 0.0000e+00
# Epoch 172/300
#  - 0s - loss: 4.8799 - categorical_accuracy: 0.0000e+00
# Epoch 173/300
#  - 0s - loss: 4.8742 - categorical_accuracy: 0.0000e+00
# Epoch 174/300
#  - 0s - loss: 4.8684 - categorical_accuracy: 0.0000e+00
# Epoch 175/300
#  - 0s - loss: 4.8627 - categorical_accuracy: 0.0000e+00
# Epoch 176/300
#  - 0s - loss: 4.8570 - categorical_accuracy: 0.0000e+00
# Epoch 177/300
#  - 0s - loss: 4.8515 - categorical_accuracy: 0.0000e+00
# Epoch 178/300
#  - 0s - loss: 4.8459 - categorical_accuracy: 0.0000e+00
# Epoch 179/300
#  - 0s - loss: 4.8404 - categorical_accuracy: 0.0000e+00
# Epoch 180/300
#  - 0s - loss: 4.8349 - categorical_accuracy: 1.0000
# Epoch 181/300
#  - 0s - loss: 4.8294 - categorical_accuracy: 1.0000
# Epoch 182/300
#  - 0s - loss: 4.8239 - categorical_accuracy: 1.0000
# Epoch 183/300
#  - 0s - loss: 4.8185 - categorical_accuracy: 1.0000
# Epoch 184/300
#  - 0s - loss: 4.8131 - categorical_accuracy: 1.0000
# Epoch 185/300
#  - 0s - loss: 4.8078 - categorical_accuracy: 1.0000
# Epoch 186/300
#  - 0s - loss: 4.8024 - categorical_accuracy: 1.0000
# Epoch 187/300
#  - 0s - loss: 4.7971 - categorical_accuracy: 1.0000
# Epoch 188/300
#  - 0s - loss: 4.7918 - categorical_accuracy: 1.0000
# Epoch 189/300
#  - 0s - loss: 4.7865 - categorical_accuracy: 1.0000
# Epoch 190/300
#  - 0s - loss: 4.7812 - categorical_accuracy: 1.0000
# Epoch 191/300
#  - 0s - loss: 4.7760 - categorical_accuracy: 1.0000
# Epoch 192/300
#  - 0s - loss: 4.7708 - categorical_accuracy: 1.0000
# Epoch 193/300
#  - 0s - loss: 4.7657 - categorical_accuracy: 1.0000
# Epoch 194/300
#  - 0s - loss: 4.7606 - categorical_accuracy: 1.0000
# Epoch 195/300
#  - 0s - loss: 4.7556 - categorical_accuracy: 1.0000
# Epoch 196/300
#  - 0s - loss: 4.7504 - categorical_accuracy: 1.0000
# Epoch 197/300
#  - 0s - loss: 4.7452 - categorical_accuracy: 1.0000
# Epoch 198/300
#  - 0s - loss: 4.7401 - categorical_accuracy: 1.0000
# Epoch 199/300
#  - 0s - loss: 4.7350 - categorical_accuracy: 1.0000
# Epoch 200/300
#  - 0s - loss: 4.7300 - categorical_accuracy: 1.0000
# Epoch 201/300
#  - 0s - loss: 4.7250 - categorical_accuracy: 1.0000
# Epoch 202/300
#  - 0s - loss: 4.7199 - categorical_accuracy: 1.0000
# Epoch 203/300
#  - 0s - loss: 4.7148 - categorical_accuracy: 1.0000
# Epoch 204/300
#  - 0s - loss: 4.7097 - categorical_accuracy: 1.0000
# Epoch 205/300
#  - 0s - loss: 4.7047 - categorical_accuracy: 1.0000
# Epoch 206/300
#  - 0s - loss: 4.6995 - categorical_accuracy: 1.0000
# Epoch 207/300
#  - 0s - loss: 4.6945 - categorical_accuracy: 1.0000
# Epoch 208/300
#  - 0s - loss: 4.6894 - categorical_accuracy: 1.0000
# Epoch 209/300
#  - 0s - loss: 4.6843 - categorical_accuracy: 1.0000
# Epoch 210/300
#  - 0s - loss: 4.6793 - categorical_accuracy: 1.0000
# Epoch 211/300
#  - 0s - loss: 4.6743 - categorical_accuracy: 1.0000
# Epoch 212/300
#  - 0s - loss: 4.6694 - categorical_accuracy: 1.0000
# Epoch 213/300
#  - 0s - loss: 4.6645 - categorical_accuracy: 1.0000
# Epoch 214/300
#  - 0s - loss: 4.6595 - categorical_accuracy: 1.0000
# Epoch 215/300
#  - 0s - loss: 4.6545 - categorical_accuracy: 1.0000
# Epoch 216/300
#  - 0s - loss: 4.6495 - categorical_accuracy: 1.0000
# Epoch 217/300
#  - 0s - loss: 4.6446 - categorical_accuracy: 1.0000
# Epoch 218/300
#  - 0s - loss: 4.6395 - categorical_accuracy: 1.0000
# Epoch 219/300
#  - 0s - loss: 4.6345 - categorical_accuracy: 1.0000
# Epoch 220/300
#  - 0s - loss: 4.6294 - categorical_accuracy: 1.0000
# Epoch 221/300
#  - 0s - loss: 4.6242 - categorical_accuracy: 1.0000
# Epoch 222/300
#  - 0s - loss: 4.6191 - categorical_accuracy: 1.0000
# Epoch 223/300
#  - 0s - loss: 4.6140 - categorical_accuracy: 1.0000
# Epoch 224/300
#  - 0s - loss: 4.6089 - categorical_accuracy: 1.0000
# Epoch 225/300
#  - 0s - loss: 4.6039 - categorical_accuracy: 1.0000
# Epoch 226/300
#  - 0s - loss: 4.5989 - categorical_accuracy: 1.0000
# Epoch 227/300
#  - 0s - loss: 4.5939 - categorical_accuracy: 1.0000
# Epoch 228/300
#  - 0s - loss: 4.5889 - categorical_accuracy: 1.0000
# Epoch 229/300
#  - 0s - loss: 4.5839 - categorical_accuracy: 1.0000
# Epoch 230/300
#  - 0s - loss: 4.5788 - categorical_accuracy: 1.0000
# Epoch 231/300
#  - 0s - loss: 4.5739 - categorical_accuracy: 1.0000
# Epoch 232/300
#  - 0s - loss: 4.5689 - categorical_accuracy: 1.0000
# Epoch 233/300
#  - 0s - loss: 4.5640 - categorical_accuracy: 1.0000
# Epoch 234/300
#  - 0s - loss: 4.5591 - categorical_accuracy: 1.0000
# Epoch 235/300
#  - 0s - loss: 4.5542 - categorical_accuracy: 1.0000
# Epoch 236/300
#  - 0s - loss: 4.5493 - categorical_accuracy: 1.0000
# Epoch 237/300
#  - 0s - loss: 4.5444 - categorical_accuracy: 1.0000
# Epoch 238/300
#  - 0s - loss: 4.5396 - categorical_accuracy: 1.0000
# Epoch 239/300
#  - 0s - loss: 4.5348 - categorical_accuracy: 1.0000
# Epoch 240/300
#  - 0s - loss: 4.5300 - categorical_accuracy: 1.0000
# Epoch 241/300
#  - 0s - loss: 4.5253 - categorical_accuracy: 1.0000
# Epoch 242/300
#  - 0s - loss: 4.5206 - categorical_accuracy: 1.0000
# Epoch 243/300
#  - 0s - loss: 4.5159 - categorical_accuracy: 1.0000
# Epoch 244/300
#  - 0s - loss: 4.5113 - categorical_accuracy: 1.0000
# Epoch 245/300
#  - 0s - loss: 4.5066 - categorical_accuracy: 1.0000
# Epoch 246/300
#  - 0s - loss: 4.5019 - categorical_accuracy: 1.0000
# Epoch 247/300
#  - 0s - loss: 4.4972 - categorical_accuracy: 1.0000
# Epoch 248/300
#  - 0s - loss: 4.4925 - categorical_accuracy: 1.0000
# Epoch 249/300
#  - 0s - loss: 4.4879 - categorical_accuracy: 1.0000
# Epoch 250/300
#  - 0s - loss: 4.4833 - categorical_accuracy: 1.0000
# Epoch 251/300
#  - 0s - loss: 4.4786 - categorical_accuracy: 1.0000
# Epoch 252/300
#  - 0s - loss: 4.4741 - categorical_accuracy: 1.0000
# Epoch 253/300
#  - 0s - loss: 4.4695 - categorical_accuracy: 1.0000
# Epoch 254/300
#  - 0s - loss: 4.4649 - categorical_accuracy: 1.0000
# Epoch 255/300
#  - 0s - loss: 4.4604 - categorical_accuracy: 1.0000
# Epoch 256/300
#  - 0s - loss: 4.4558 - categorical_accuracy: 1.0000
# Epoch 257/300
#  - 0s - loss: 4.4512 - categorical_accuracy: 1.0000
# Epoch 258/300
#  - 0s - loss: 4.4467 - categorical_accuracy: 1.0000
# Epoch 259/300
#  - 0s - loss: 4.4422 - categorical_accuracy: 1.0000
# Epoch 260/300
#  - 0s - loss: 4.4377 - categorical_accuracy: 1.0000
# Epoch 261/300
#  - 0s - loss: 4.4332 - categorical_accuracy: 1.0000
# Epoch 262/300
#  - 0s - loss: 4.4287 - categorical_accuracy: 1.0000
# Epoch 263/300
#  - 0s - loss: 4.4241 - categorical_accuracy: 1.0000
# Epoch 264/300
#  - 0s - loss: 4.4196 - categorical_accuracy: 1.0000
# Epoch 265/300
#  - 0s - loss: 4.4151 - categorical_accuracy: 1.0000
# Epoch 266/300
#  - 0s - loss: 4.4106 - categorical_accuracy: 1.0000
# Epoch 267/300
#  - 0s - loss: 4.4062 - categorical_accuracy: 1.0000
# Epoch 268/300
#  - 0s - loss: 4.4017 - categorical_accuracy: 1.0000
# Epoch 269/300
#  - 0s - loss: 4.3972 - categorical_accuracy: 1.0000
# Epoch 270/300
#  - 0s - loss: 4.3927 - categorical_accuracy: 1.0000
# Epoch 271/300
#  - 0s - loss: 4.3882 - categorical_accuracy: 1.0000
# Epoch 272/300
#  - 0s - loss: 4.3836 - categorical_accuracy: 1.0000
# Epoch 273/300
#  - 0s - loss: 4.3791 - categorical_accuracy: 1.0000
# Epoch 274/300
#  - 0s - loss: 4.3745 - categorical_accuracy: 1.0000
# Epoch 275/300
#  - 0s - loss: 4.3700 - categorical_accuracy: 1.0000
# Epoch 276/300
#  - 0s - loss: 4.3656 - categorical_accuracy: 1.0000
# Epoch 277/300
#  - 0s - loss: 4.3612 - categorical_accuracy: 1.0000
# Epoch 278/300
#  - 0s - loss: 4.3568 - categorical_accuracy: 1.0000
# Epoch 279/300
#  - 0s - loss: 4.3523 - categorical_accuracy: 1.0000
# Epoch 280/300
#  - 0s - loss: 4.3479 - categorical_accuracy: 1.0000
# Epoch 281/300
#  - 0s - loss: 4.3435 - categorical_accuracy: 1.0000
# Epoch 282/300
#  - 0s - loss: 4.3391 - categorical_accuracy: 1.0000
# Epoch 283/300
#  - 0s - loss: 4.3347 - categorical_accuracy: 1.0000
# Epoch 284/300
#  - 0s - loss: 4.3304 - categorical_accuracy: 1.0000
# Epoch 285/300
#  - 0s - loss: 4.3260 - categorical_accuracy: 1.0000
# Epoch 286/300
#  - 0s - loss: 4.3216 - categorical_accuracy: 1.0000
# Epoch 287/300
#  - 0s - loss: 4.3173 - categorical_accuracy: 1.0000
# Epoch 288/300
#  - 0s - loss: 4.3130 - categorical_accuracy: 1.0000
# Epoch 289/300
#  - 0s - loss: 4.3087 - categorical_accuracy: 1.0000
# Epoch 290/300
#  - 0s - loss: 4.3045 - categorical_accuracy: 1.0000
# Epoch 291/300
#  - 0s - loss: 4.3002 - categorical_accuracy: 1.0000
# Epoch 292/300
#  - 0s - loss: 4.2960 - categorical_accuracy: 1.0000
# Epoch 293/300
#  - 0s - loss: 4.2917 - categorical_accuracy: 1.0000
# Epoch 294/300
#  - 0s - loss: 4.2874 - categorical_accuracy: 1.0000
# Epoch 295/300
#  - 0s - loss: 4.2830 - categorical_accuracy: 1.0000
# Epoch 296/300
#  - 0s - loss: 4.2787 - categorical_accuracy: 1.0000
# Epoch 297/300
#  - 0s - loss: 4.2744 - categorical_accuracy: 1.0000
# Epoch 298/300
#  - 0s - loss: 4.2702 - categorical_accuracy: 1.0000
# Epoch 299/300
#  - 0s - loss: 4.2659 - categorical_accuracy: 1.0000
# Epoch 300/300
#  - 0s - loss: 4.2617 - categorical_accuracy: 1.0000

# %%
#adversarial_model.load_weights('./adversarial_weights_resnet.h5')
ruido = adversarial_model.get_weights()[0].reshape((224,224,3))
#ruido = 55* ruido
#img_pre = preprocessImg(ruido + x_not_pre)
plotImage(ruido)
print('Imagen')
print(x)
print('Ruido')
print(ruido)
imagen_adversarial = x + ruido
print(imagen_adversarial.shape)
plotImage(x[0])
plotImage(imagen_adversarial[0])
plotImage(imagen_adversarial[0] - x[0])
print(decode_predictions(model.predict(imagen_adversarial), top=3)[0])
print(clasifica_mod_adversarial({'image':x,'unity':np.ones(shape=(1,1))}, adversarial_model))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Imagen
# [[[[ -67.619      -95.558     -101.619    ]
#    [ -74.619     -106.558     -114.619    ]
#    [ -66.619     -102.558     -113.619    ]
#    ...
#    [ -10.619003   -21.557999   -16.619003 ]
#    [  -3.6190033  -14.557999    -9.619003 ]
#    [  -7.6190033  -18.557999   -13.619003 ]]
#
#   [[ -74.619     -102.558     -107.619    ]
#    [ -72.619     -104.558     -110.619    ]
#    [ -61.619003   -98.558     -107.619    ]
#    ...
#    [  -4.6190033  -16.557999    -9.619003 ]
#    [   3.3809967  -10.557999    -4.6190033]
#    [  -9.619003   -23.557999   -17.619003 ]]
#
#   [[ -77.619     -107.558     -113.619    ]
#    [ -61.619003   -93.558     -101.619    ]
#    [ -74.619     -109.558     -118.619    ]
#    ...
#    [   1.3809967   -9.557999    -2.6190033]
#    [  -7.6190033  -20.557999   -17.619003 ]
#    [ -22.619003   -35.558      -32.619003 ]]
#
#   ...
#
#   [[-214.619     -194.558     -171.619    ]
#    [-169.619     -149.558     -119.619    ]
#    [-170.619     -146.558     -111.619    ]
#    ...
#    [-126.619      -97.558      -71.619    ]
#    [-140.619     -108.558      -78.619    ]
#    [-129.619      -97.558      -67.619    ]]
#
#   [[-135.619     -108.558      -87.619    ]
#    [-152.619     -127.558      -98.619    ]
#    [-136.619     -112.558      -77.619    ]
#    ...
#    [-126.619      -97.558      -71.619    ]
#    [-149.619     -111.558      -82.619    ]
#    [-139.619     -101.558      -72.619    ]]
#
#   [[-122.619      -86.558      -68.619    ]
#    [-108.619      -79.558      -47.619003 ]
#    [-138.619     -111.558      -79.619    ]
#    ...
#    [-139.619     -108.558      -80.619    ]
#    [-125.619      -88.558      -61.619003 ]
#    [-150.619     -113.558      -86.619    ]]]]
# Ruido
# [[[-2.4033050e-01 -5.0215542e-01  5.0396800e-01]
#   [-4.8846623e-01 -2.3627509e-01  6.5649068e-01]
#   [-7.5105481e-02 -3.1762976e-02  7.8265834e-01]
#   ...
#   [-5.2484709e-01 -5.3835750e-01 -4.8282412e-01]
#   [-4.5063123e-01 -5.7224745e-01 -5.3277910e-01]
#   [-6.6612971e-01 -6.0965472e-01 -4.5659906e-01]]
#
#  [[-1.3871069e-01 -3.4292644e-01  6.3719320e-01]
#   [-5.6437880e-01 -1.4246546e-01  6.2387741e-01]
#   [-7.2257388e-01 -2.8569528e-01  6.7591631e-01]
#   ...
#   [-5.9212869e-01 -6.0163885e-01 -7.1881872e-01]
#   [-7.1284509e-01 -7.7314913e-01 -2.4057849e-01]
#   [ 4.8215404e-01  5.0335884e-01  4.7097617e-01]]
#
#  [[ 3.5565665e-01  4.9197033e-02  7.0272344e-01]
#   [-7.6007265e-01 -2.4108444e-01  5.9390289e-01]
#   [-5.1098162e-01 -4.2214805e-01  3.3360240e-01]
#   ...
#   [-4.8999918e-01 -7.5242090e-01 -7.7908170e-01]
#   [ 7.8309834e-01  5.0406879e-01  5.6000584e-01]
#   [ 7.9777038e-01  7.3734397e-01  6.8370140e-01]]
#
#  ...
#
#  [[ 5.8028072e-01 -6.0171622e-01 -6.4594787e-01]
#   [ 5.8694041e-01 -2.4551943e-01 -4.9936569e-01]
#   [ 6.0339081e-01  1.2965000e-01 -3.7094760e-01]
#   ...
#   [ 1.8406363e-01 -1.3781869e-01 -6.3533723e-01]
#   [ 8.1530535e-01  5.0340086e-01 -4.3758941e-01]
#   [-2.3769850e-01 -7.6134678e-04 -2.6198971e-01]]
#
#  [[ 2.2598463e-01 -6.4200789e-02 -7.9314387e-01]
#   [ 1.5267442e-01 -3.0542919e-01 -2.5272265e-01]
#   [ 1.2451431e-01 -3.9453757e-01 -1.8742272e-01]
#   ...
#   [ 5.0386095e-01  3.1504783e-01  1.9879922e-01]
#   [ 5.9961891e-01 -4.4134903e-01  9.8951921e-02]
#   [-6.3314617e-01 -5.8919531e-01 -2.8806216e-01]]
#
#  [[ 3.2606405e-01  3.0414048e-01  3.5542735e-01]
#   [ 4.2575148e-01  6.3427562e-01  3.9756304e-01]
#   [ 2.9151257e-02 -5.9503192e-01 -7.7892065e-01]
#   ...
#   [ 4.8020032e-01  2.2815388e-01  4.0508017e-01]
#   [-5.9902227e-01 -5.6449252e-01 -2.7579638e-01]
#   [-5.0330198e-01 -4.8245355e-01 -3.5588446e-01]]]
# (1, 224, 224, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [('n02504458', 'African_elephant', 0.82602465), ('n01871265', 'tusker', 0.11659011), ('n02504013', 'Indian_elephant', 0.056074932)]
# [('n02504458', 'African_elephant', 0.82602465), ('n01871265', 'tusker', 0.11659011), ('n02504013', 'Indian_elephant', 0.056074932)]

# %%
adversarial_model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# unity (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# adversarial_noise (Dense)       (None, 150528)       150528      unity[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 224, 224, 3)  0           adversarial_noise[0][0]
# __________________________________________________________________________________________________
# image (InputLayer)              (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 3)  0           reshape[0][0]
#                                                                  image[0][0]
# __________________________________________________________________________________________________
# resnet50 (Model)                (None, 1000)         25636712    add[0][0]
# __________________________________________________________________________________________________
# reshape_resnet (Reshape)        (None, 1000)         0           resnet50[10][0]
# ==================================================================================================
# Total params: 25,787,240
# Trainable params: 150,528
# Non-trainable params: 25,636,712
# __________________________________________________________________________________________________

# %%
target_vector = np.zeros((1,1000))
target_vector[0,4] = 1
pred = model.predict(x)
print(np.argmax(pred))
print(np.argmax(target_vector))
print(adversarial_model.evaluate({'image':x,'unity':np.ones(shape=(1,1))}, target_vector))
